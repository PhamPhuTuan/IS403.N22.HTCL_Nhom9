# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install tensorflow --quiet

# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import libraries for working with dates and times
import datetime as dt

# Import TensorFlow and Keras libraries for building and training neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, Reshape, Flatten, GRU
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

# Import scikit-learn library for various metrics and preprocessing tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Import matplotlib library for creating plots and charts
import matplotlib.pyplot as plt

# Magic command to display plots inline in the Jupyter Notebook
# %matplotlib inline

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# Read in the Gold dataset from a CSV file
df=pd.read_csv("/content/drive/MyDrive/PTDLKD/Data/Gold_Data.csv")
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %% [markdown]
# # Preprocessing Data
#
# ---

# %%
# Format column Date
df.index = pd.to_datetime(df.index,format='%m/%d/%Y')

# Format column Price to float
df['Price'] = df.Price.str.replace(',','').astype(float)

# Flip the column
df = df.iloc[::-1]

# Create new Dataframe
df1 = pd.DataFrame(df, columns=['Date', 'Price'])
df1.drop('Date', axis = 1, inplace = True)

# Plot the 'price' column of the 'df' DataFrame
plt.figure(figsize=(16,5))
plt.plot(df1['Price'])
plt.title('Prices of Gold')
plt.show()

# %% [markdown]
# # Split dataset (7-2-1)
#
# ---

# %%
# Create a MinMaxScaler object with a specified range
data = df1.values
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)

# Split the data
train_size = int(0.7 * len(sc_train))
test_size = int(0.2 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an GRU layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an GRU layer with 50 units
model.add(GRU(50,return_sequences=True))

# Add an GRU layer with 50 units
model.add(GRU(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_7_2_1.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.21533, saving model to save_model_7_2_1.hdf5
# 19/19 - 7s - loss: 0.2153 - 7s/epoch - 387ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.21533 to 0.06520, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0652 - 416ms/epoch - 22ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.06520 to 0.02592, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0259 - 411ms/epoch - 22ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.02592 to 0.02403, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0240 - 449ms/epoch - 24ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02403 to 0.02246, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0225 - 406ms/epoch - 21ms/step
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.02246
# 19/19 - 0s - loss: 0.0225 - 258ms/epoch - 14ms/step
# Epoch 7/80
#
# Epoch 7: loss did not improve from 0.02246
# 19/19 - 0s - loss: 0.0266 - 251ms/epoch - 13ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.02246
# 19/19 - 0s - loss: 0.0288 - 238ms/epoch - 13ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.02246
# 19/19 - 0s - loss: 0.0283 - 253ms/epoch - 13ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.02246 to 0.02013, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0201 - 274ms/epoch - 14ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.02013
# 19/19 - 0s - loss: 0.0222 - 242ms/epoch - 13ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.02013
# 19/19 - 0s - loss: 0.0226 - 250ms/epoch - 13ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.02013
# 19/19 - 0s - loss: 0.0206 - 233ms/epoch - 12ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.02013
# 19/19 - 0s - loss: 0.0256 - 252ms/epoch - 13ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.02013
# 19/19 - 0s - loss: 0.0224 - 248ms/epoch - 13ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.02013
# 19/19 - 0s - loss: 0.0203 - 238ms/epoch - 13ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.02013
# 19/19 - 0s - loss: 0.0237 - 246ms/epoch - 13ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.02013 to 0.01992, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0199 - 300ms/epoch - 16ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.01992
# 19/19 - 0s - loss: 0.0205 - 255ms/epoch - 13ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.01992
# 19/19 - 0s - loss: 0.0225 - 254ms/epoch - 13ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.01992
# 19/19 - 0s - loss: 0.0211 - 250ms/epoch - 13ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.01992
# 19/19 - 0s - loss: 0.0218 - 255ms/epoch - 13ms/step
# Epoch 23/80
#
# Epoch 23: loss improved from 0.01992 to 0.01895, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0190 - 293ms/epoch - 15ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0200 - 247ms/epoch - 13ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0225 - 264ms/epoch - 14ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0198 - 297ms/epoch - 16ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0222 - 251ms/epoch - 13ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0205 - 242ms/epoch - 13ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0241 - 267ms/epoch - 14ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0230 - 253ms/epoch - 13ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.01895
# 19/19 - 0s - loss: 0.0199 - 238ms/epoch - 13ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.01895 to 0.01794, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0179 - 284ms/epoch - 15ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.01794
# 19/19 - 0s - loss: 0.0200 - 269ms/epoch - 14ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.01794
# 19/19 - 0s - loss: 0.0237 - 246ms/epoch - 13ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.01794 to 0.01793, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0179 - 284ms/epoch - 15ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.01793
# 19/19 - 0s - loss: 0.0273 - 247ms/epoch - 13ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01793
# 19/19 - 0s - loss: 0.0249 - 278ms/epoch - 15ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01793
# 19/19 - 0s - loss: 0.0202 - 273ms/epoch - 14ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01793
# 19/19 - 0s - loss: 0.0181 - 257ms/epoch - 14ms/step
# Epoch 40/80
#
# Epoch 40: loss improved from 0.01793 to 0.01778, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0178 - 281ms/epoch - 15ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01778
# 19/19 - 0s - loss: 0.0178 - 266ms/epoch - 14ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.01778
# 19/19 - 0s - loss: 0.0191 - 266ms/epoch - 14ms/step
# Epoch 43/80
#
# Epoch 43: loss improved from 0.01778 to 0.01737, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0174 - 398ms/epoch - 21ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.01737 to 0.01730, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0173 - 473ms/epoch - 25ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01730
# 19/19 - 0s - loss: 0.0189 - 402ms/epoch - 21ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01730
# 19/19 - 0s - loss: 0.0194 - 414ms/epoch - 22ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01730
# 19/19 - 0s - loss: 0.0195 - 374ms/epoch - 20ms/step
# Epoch 48/80
#
# Epoch 48: loss improved from 0.01730 to 0.01589, saving model to save_model_7_2_1.hdf5
# 19/19 - 1s - loss: 0.0159 - 501ms/epoch - 26ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01589
# 19/19 - 0s - loss: 0.0193 - 392ms/epoch - 21ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01589
# 19/19 - 0s - loss: 0.0162 - 388ms/epoch - 20ms/step
# Epoch 51/80
#
# Epoch 51: loss improved from 0.01589 to 0.01578, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0158 - 435ms/epoch - 23ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01578
# 19/19 - 0s - loss: 0.0177 - 373ms/epoch - 20ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01578
# 19/19 - 0s - loss: 0.0255 - 245ms/epoch - 13ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01578
# 19/19 - 0s - loss: 0.0176 - 236ms/epoch - 12ms/step
# Epoch 55/80
#
# Epoch 55: loss improved from 0.01578 to 0.01569, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0157 - 290ms/epoch - 15ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.01569
# 19/19 - 0s - loss: 0.0170 - 235ms/epoch - 12ms/step
# Epoch 57/80
#
# Epoch 57: loss improved from 0.01569 to 0.01511, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0151 - 277ms/epoch - 15ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.01511
# 19/19 - 0s - loss: 0.0155 - 249ms/epoch - 13ms/step
# Epoch 59/80
#
# Epoch 59: loss improved from 0.01511 to 0.01480, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0148 - 338ms/epoch - 18ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01480
# 19/19 - 0s - loss: 0.0149 - 316ms/epoch - 17ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01480
# 19/19 - 0s - loss: 0.0158 - 299ms/epoch - 16ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01480
# 19/19 - 0s - loss: 0.0154 - 312ms/epoch - 16ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01480
# 19/19 - 0s - loss: 0.0149 - 292ms/epoch - 15ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01480
# 19/19 - 0s - loss: 0.0162 - 297ms/epoch - 16ms/step
# Epoch 65/80
#
# Epoch 65: loss improved from 0.01480 to 0.01385, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0138 - 313ms/epoch - 16ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01385
# 19/19 - 0s - loss: 0.0147 - 223ms/epoch - 12ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01385
# 19/19 - 0s - loss: 0.0215 - 241ms/epoch - 13ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01385
# 19/19 - 0s - loss: 0.0155 - 259ms/epoch - 14ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01385
# 19/19 - 0s - loss: 0.0141 - 265ms/epoch - 14ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01385
# 19/19 - 0s - loss: 0.0165 - 244ms/epoch - 13ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01385
# 19/19 - 0s - loss: 0.0146 - 246ms/epoch - 13ms/step
# Epoch 72/80
#
# Epoch 72: loss improved from 0.01385 to 0.01340, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0134 - 256ms/epoch - 13ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01340
# 19/19 - 0s - loss: 0.0180 - 240ms/epoch - 13ms/step
# Epoch 74/80
#
# Epoch 74: loss improved from 0.01340 to 0.01315, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0131 - 259ms/epoch - 14ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01315
# 19/19 - 0s - loss: 0.0170 - 247ms/epoch - 13ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01315
# 19/19 - 0s - loss: 0.0133 - 236ms/epoch - 12ms/step
# Epoch 77/80
#
# Epoch 77: loss improved from 0.01315 to 0.01301, saving model to save_model_7_2_1.hdf5
# 19/19 - 0s - loss: 0.0130 - 275ms/epoch - 14ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01301
# 19/19 - 0s - loss: 0.0146 - 238ms/epoch - 13ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01301
# 19/19 - 0s - loss: 0.0137 - 247ms/epoch - 13ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01301
# 19/19 - 0s - loss: 0.0137 - 239ms/epoch - 13ms/step

# %%
# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_7_2_1.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 29/29 [==============================] - 3s 8ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 5ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 8ms/step

# %%
# Dự báo dữ liệu test, val
train_predict=model.predict(x_train)
y_pred=model.predict(x_test)
y_pred_val=model.predict(x_val)

# Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=sc.inverse_transform(train_predict)
y_pred=sc.inverse_transform(y_pred)
y_pred_val=sc.inverse_transform(y_pred_val)
# Out:
# 29/29 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 5ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 5:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 5)
# [0.9419471425344477, 0.9085159250056472, 0.8998192907160605, 0.8724870115202168, 0.8975604246668172]

# %%
# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.9092997908592224], [0.9165665507316589], [0.9210212230682373], [0.9246434569358826], [0.9293031692504883], [0.9345116019248962], [0.9398419857025146], [0.9450643658638], [0.950160026550293], [0.9552003741264343], [0.9602283835411072], [0.9652513265609741], [0.970259428024292], [0.9752427935600281], [0.9801977276802063], [0.9851236939430237], [0.9900208711624146], [0.9948882460594177], [0.9997251033782959], [1.0045294761657715], [1.0093001127243042], [1.014035940170288], [1.0187355279922485], [1.0233975648880005], [1.028021216392517], [1.0326051712036133], [1.0371482372283936], [1.0416498184204102], [1.0461084842681885], [1.0505229234695435]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['Date'].astype(str).tolist()

# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%m/%d/%Y').date() for date in datelist_train]

# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[1989.09403483]
#  [1995.52802402]
#  [1999.4721909 ]
#  [2002.67931677]
#  [2006.80502605]
#  [2011.41657234]
#  [2016.13609414]
#  [2020.75998954]
#  [2025.27168751]
#  [2029.73441125]
#  [2034.18621079]
#  [2038.63352454]
#  [2043.06769757]
#  [2047.47996942]
#  [2051.86706809]
#  [2056.22851862]
#  [2060.56447933]
#  [2064.87405306]
#  [2069.15660653]
#  [2073.4103982 ]
#  [2077.63431981]
#  [2081.82742143]
#  [2085.98843648]
#  [2090.11620395]
#  [2094.20998499]
#  [2098.26861858]
#  [2102.29104924]
#  [2106.27674923]
#  [2110.22445197]
#  [2114.13299644]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  14.806085322906615
# MAPE:  0.8208258341317671
# RMSE:  19.128395275347664
#
# ** Validate **
# MAE:  14.3316229717548
# MAPE:  0.751883129964853
# RMSE:  19.004088038066993

# %% [markdown]
# # Split dataset (6-3-1)
#
# ---

# %%
# Split the data
train_size = int(0.6 * len(sc_train))
test_size = int(0.3 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an GRU layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an GRU layer with 50 units
model.add(GRU(50,return_sequences=True))

# Add an GRU layer with 50 units
model.add(GRU(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_6_3_1.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.20354, saving model to save_model_6_3_1.hdf5
# 16/16 - 7s - loss: 0.2035 - 7s/epoch - 462ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.20354 to 0.04909, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0491 - 220ms/epoch - 14ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.04909 to 0.02585, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0258 - 222ms/epoch - 14ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.02585 to 0.02418, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0242 - 388ms/epoch - 24ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02418 to 0.02138, saving model to save_model_6_3_1.hdf5
# 16/16 - 1s - loss: 0.0214 - 504ms/epoch - 32ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.02138 to 0.02072, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0207 - 385ms/epoch - 24ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.02072 to 0.01969, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0197 - 314ms/epoch - 20ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.01969 to 0.01959, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0196 - 221ms/epoch - 14ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0204 - 177ms/epoch - 11ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0213 - 195ms/epoch - 12ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0212 - 197ms/epoch - 12ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0207 - 228ms/epoch - 14ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0204 - 188ms/epoch - 12ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0209 - 173ms/epoch - 11ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0215 - 192ms/epoch - 12ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0199 - 184ms/epoch - 11ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.01959
# 16/16 - 0s - loss: 0.0196 - 179ms/epoch - 11ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.01959 to 0.01888, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0189 - 221ms/epoch - 14ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.01888 to 0.01863, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0186 - 238ms/epoch - 15ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.01863
# 16/16 - 0s - loss: 0.0214 - 244ms/epoch - 15ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.01863
# 16/16 - 0s - loss: 0.0200 - 179ms/epoch - 11ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.01863
# 16/16 - 0s - loss: 0.0193 - 188ms/epoch - 12ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.01863
# 16/16 - 0s - loss: 0.0190 - 176ms/epoch - 11ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.01863
# 16/16 - 0s - loss: 0.0192 - 176ms/epoch - 11ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.01863
# 16/16 - 0s - loss: 0.0188 - 168ms/epoch - 11ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.01863 to 0.01808, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0181 - 251ms/epoch - 16ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.01808
# 16/16 - 0s - loss: 0.0186 - 192ms/epoch - 12ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.01808
# 16/16 - 0s - loss: 0.0192 - 194ms/epoch - 12ms/step
# Epoch 29/80
#
# Epoch 29: loss improved from 0.01808 to 0.01797, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0180 - 238ms/epoch - 15ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.01797 to 0.01775, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0177 - 239ms/epoch - 15ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.01775
# 16/16 - 0s - loss: 0.0178 - 201ms/epoch - 13ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.01775
# 16/16 - 0s - loss: 0.0178 - 226ms/epoch - 14ms/step
# Epoch 33/80
#
# Epoch 33: loss improved from 0.01775 to 0.01745, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0175 - 220ms/epoch - 14ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.01745
# 16/16 - 0s - loss: 0.0184 - 184ms/epoch - 11ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.01745
# 16/16 - 0s - loss: 0.0178 - 199ms/epoch - 12ms/step
# Epoch 36/80
#
# Epoch 36: loss improved from 0.01745 to 0.01692, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0169 - 269ms/epoch - 17ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01692
# 16/16 - 1s - loss: 0.0171 - 532ms/epoch - 33ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01692
# 16/16 - 1s - loss: 0.0191 - 537ms/epoch - 34ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01692
# 16/16 - 1s - loss: 0.0188 - 666ms/epoch - 42ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.01692
# 16/16 - 1s - loss: 0.0198 - 777ms/epoch - 49ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01692
# 16/16 - 1s - loss: 0.0174 - 713ms/epoch - 45ms/step
# Epoch 42/80
#
# Epoch 42: loss improved from 0.01692 to 0.01588, saving model to save_model_6_3_1.hdf5
# 16/16 - 1s - loss: 0.0159 - 755ms/epoch - 47ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.01588
# 16/16 - 1s - loss: 0.0166 - 717ms/epoch - 45ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01588
# 16/16 - 1s - loss: 0.0189 - 759ms/epoch - 47ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01588
# 16/16 - 1s - loss: 0.0190 - 642ms/epoch - 40ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01588
# 16/16 - 0s - loss: 0.0163 - 455ms/epoch - 28ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01588
# 16/16 - 1s - loss: 0.0165 - 526ms/epoch - 33ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01588
# 16/16 - 1s - loss: 0.0160 - 530ms/epoch - 33ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01588
# 16/16 - 1s - loss: 0.0173 - 854ms/epoch - 53ms/step
# Epoch 50/80
#
# Epoch 50: loss improved from 0.01588 to 0.01559, saving model to save_model_6_3_1.hdf5
# 16/16 - 1s - loss: 0.0156 - 544ms/epoch - 34ms/step
# Epoch 51/80
#
# Epoch 51: loss improved from 0.01559 to 0.01435, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0143 - 344ms/epoch - 22ms/step
# Epoch 52/80
#
# Epoch 52: loss improved from 0.01435 to 0.01398, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0140 - 430ms/epoch - 27ms/step
# Epoch 53/80
#
# Epoch 53: loss improved from 0.01398 to 0.01388, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0139 - 426ms/epoch - 27ms/step
# Epoch 54/80
#
# Epoch 54: loss improved from 0.01388 to 0.01375, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0138 - 349ms/epoch - 22ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01375
# 16/16 - 0s - loss: 0.0162 - 380ms/epoch - 24ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.01375
# 16/16 - 0s - loss: 0.0162 - 387ms/epoch - 24ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.01375
# 16/16 - 0s - loss: 0.0146 - 366ms/epoch - 23ms/step
# Epoch 58/80
#
# Epoch 58: loss improved from 0.01375 to 0.01324, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0132 - 366ms/epoch - 23ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01324
# 16/16 - 0s - loss: 0.0133 - 279ms/epoch - 17ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01324
# 16/16 - 0s - loss: 0.0133 - 223ms/epoch - 14ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01324
# 16/16 - 0s - loss: 0.0142 - 179ms/epoch - 11ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01324
# 16/16 - 0s - loss: 0.0147 - 173ms/epoch - 11ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01324
# 16/16 - 0s - loss: 0.0133 - 188ms/epoch - 12ms/step
# Epoch 64/80
#
# Epoch 64: loss improved from 0.01324 to 0.01278, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0128 - 200ms/epoch - 13ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0146 - 191ms/epoch - 12ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0149 - 225ms/epoch - 14ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0183 - 214ms/epoch - 13ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0141 - 301ms/epoch - 19ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0138 - 177ms/epoch - 11ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0136 - 212ms/epoch - 13ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0128 - 249ms/epoch - 16ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0138 - 316ms/epoch - 20ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0138 - 300ms/epoch - 19ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01278
# 16/16 - 1s - loss: 0.0161 - 544ms/epoch - 34ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0132 - 472ms/epoch - 29ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0134 - 303ms/epoch - 19ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0129 - 295ms/epoch - 18ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0136 - 275ms/epoch - 17ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0143 - 285ms/epoch - 18ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01278
# 16/16 - 0s - loss: 0.0152 - 298ms/epoch - 19ms/step

# %%
# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_6_3_1.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 25/25 [==============================] - 2s 3ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 13/13 [==============================] - 0s 3ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 7ms/step

# %%
# Dự báo dữ liệu test, val
train_predict=model.predict(x_train)
y_pred=model.predict(x_test)
y_pred_val=model.predict(x_val)

# Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=sc.inverse_transform(train_predict)
y_pred=sc.inverse_transform(y_pred)
y_pred_val=sc.inverse_transform(y_pred_val)
# Out:
# 25/25 [==============================] - 3s 6ms/step
# 13/13 [==============================] - 0s 8ms/step
# 5/5 [==============================] - 0s 10ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 5:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 5)
# [0.9419471425344477, 0.9085159250056472, 0.8998192907160605, 0.8724870115202168, 0.8975604246668172]

# %%
# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.9013162851333618], [0.900937557220459], [0.8985067009925842], [0.895940899848938], [0.8942520022392273], [0.892911434173584], [0.891646146774292], [0.8903422355651855], [0.8890044689178467], [0.8876674175262451], [0.8863482475280762], [0.8850492238998413], [0.8837675452232361], [0.8825008273124695], [0.8812480568885803], [0.8800091743469238], [0.8787837624549866], [0.8775721192359924], [0.8763738870620728], [0.8751886487007141], [0.874016523361206], [0.8728571534156799], [0.8717104196548462], [0.8705761432647705], [0.8694539070129395], [0.8683436512947083], [0.8672451376914978], [0.866158127784729], [0.8650826215744019], [0.8640185594558716]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[1982.02543886]
#  [1981.69011316]
#  [1979.53783306]
#  [1977.26607273]
#  [1975.77072278]
#  [1974.58378382]
#  [1973.46349835]
#  [1972.30901537]
#  [1971.12455678]
#  [1969.94073148]
#  [1968.77273836]
#  [1967.62258284]
#  [1966.48778454]
#  [1965.3662325 ]
#  [1964.25702957]
#  [1963.16012297]
#  [1962.07514328]
#  [1961.00235437]
#  [1959.9414396 ]
#  [1958.89202956]
#  [1957.85422978]
#  [1956.82772363]
#  [1955.81240556]
#  [1954.80811725]
#  [1953.81448927]
#  [1952.83146886]
#  [1951.85884491]
#  [1950.89640634]
#  [1949.94415314]
#  [1949.00203254]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  15.574616359435405
# MAPE:  0.8646937342461058
# RMSE:  20.300999456454434
#
# ** Validate **
# MAE:  15.812117202409343
# MAPE:  0.8313473712618018
# RMSE:  20.716257143137558

# %% [markdown]
# # Split dataset (5-3-2)
#
# ---

# %%
# Split the data
train_size = int(0.5 * len(sc_train))
test_size = int(0.3 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an GRU layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an GRU layer with 50 units
model.add(GRU(50,return_sequences=True))

# Add an GRU layer with 50 units
model.add(GRU(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_5_3_2.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.19607, saving model to save_model_5_3_2.hdf5
# 13/13 - 17s - loss: 0.1961 - 17s/epoch - 1s/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.19607 to 0.07637, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0764 - 161ms/epoch - 12ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.07637 to 0.03651, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0365 - 168ms/epoch - 13ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03651 to 0.02500, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0250 - 187ms/epoch - 14ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02500 to 0.02184, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0218 - 163ms/epoch - 13ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.02184 to 0.01953, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0195 - 172ms/epoch - 13ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.01953 to 0.01914, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0191 - 185ms/epoch - 14ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.01914
# 13/13 - 0s - loss: 0.0203 - 143ms/epoch - 11ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.01914
# 13/13 - 0s - loss: 0.0204 - 146ms/epoch - 11ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.01914
# 13/13 - 0s - loss: 0.0198 - 147ms/epoch - 11ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.01914 to 0.01883, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0188 - 165ms/epoch - 13ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.01883 to 0.01871, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0187 - 175ms/epoch - 13ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.01871
# 13/13 - 0s - loss: 0.0188 - 187ms/epoch - 14ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.01871
# 13/13 - 0s - loss: 0.0188 - 233ms/epoch - 18ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.01871
# 13/13 - 0s - loss: 0.0191 - 240ms/epoch - 18ms/step
# Epoch 16/80
#
# Epoch 16: loss improved from 0.01871 to 0.01856, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0186 - 267ms/epoch - 21ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.01856
# 13/13 - 0s - loss: 0.0187 - 267ms/epoch - 21ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.01856
# 13/13 - 0s - loss: 0.0198 - 231ms/epoch - 18ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.01856
# 13/13 - 0s - loss: 0.0186 - 226ms/epoch - 17ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.01856
# 13/13 - 0s - loss: 0.0191 - 247ms/epoch - 19ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.01856 to 0.01800, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0180 - 342ms/epoch - 26ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.01800
# 13/13 - 0s - loss: 0.0183 - 361ms/epoch - 28ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.01800
# 13/13 - 0s - loss: 0.0193 - 418ms/epoch - 32ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.01800 to 0.01787, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0179 - 451ms/epoch - 35ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.01787 to 0.01784, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0178 - 411ms/epoch - 32ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.01784
# 13/13 - 0s - loss: 0.0187 - 465ms/epoch - 36ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.01784
# 13/13 - 0s - loss: 0.0192 - 326ms/epoch - 25ms/step
# Epoch 28/80
#
# Epoch 28: loss improved from 0.01784 to 0.01772, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0177 - 396ms/epoch - 30ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.01772
# 13/13 - 0s - loss: 0.0179 - 486ms/epoch - 37ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.01772
# 13/13 - 0s - loss: 0.0182 - 342ms/epoch - 26ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.01772
# 13/13 - 0s - loss: 0.0193 - 252ms/epoch - 19ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.01772
# 13/13 - 0s - loss: 0.0180 - 242ms/epoch - 19ms/step
# Epoch 33/80
#
# Epoch 33: loss improved from 0.01772 to 0.01759, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0176 - 171ms/epoch - 13ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.01759
# 13/13 - 0s - loss: 0.0184 - 139ms/epoch - 11ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.01759
# 13/13 - 0s - loss: 0.0179 - 144ms/epoch - 11ms/step
# Epoch 36/80
#
# Epoch 36: loss improved from 0.01759 to 0.01681, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0168 - 190ms/epoch - 15ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01681
# 13/13 - 0s - loss: 0.0171 - 213ms/epoch - 16ms/step
# Epoch 38/80
#
# Epoch 38: loss improved from 0.01681 to 0.01633, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0163 - 324ms/epoch - 25ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01633
# 13/13 - 0s - loss: 0.0167 - 239ms/epoch - 18ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.01633
# 13/13 - 0s - loss: 0.0175 - 306ms/epoch - 24ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01633
# 13/13 - 0s - loss: 0.0167 - 333ms/epoch - 26ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.01633
# 13/13 - 0s - loss: 0.0167 - 284ms/epoch - 22ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.01633
# 13/13 - 0s - loss: 0.0178 - 348ms/epoch - 27ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01633
# 13/13 - 0s - loss: 0.0174 - 277ms/epoch - 21ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01633
# 13/13 - 0s - loss: 0.0176 - 253ms/epoch - 19ms/step
# Epoch 46/80
#
# Epoch 46: loss improved from 0.01633 to 0.01569, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0157 - 383ms/epoch - 29ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01569
# 13/13 - 0s - loss: 0.0173 - 254ms/epoch - 20ms/step
# Epoch 48/80
#
# Epoch 48: loss improved from 0.01569 to 0.01553, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0155 - 351ms/epoch - 27ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01553
# 13/13 - 0s - loss: 0.0158 - 252ms/epoch - 19ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01553
# 13/13 - 0s - loss: 0.0156 - 246ms/epoch - 19ms/step
# Epoch 51/80
#
# Epoch 51: loss improved from 0.01553 to 0.01450, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0145 - 437ms/epoch - 34ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01450
# 13/13 - 0s - loss: 0.0150 - 258ms/epoch - 20ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01450
# 13/13 - 0s - loss: 0.0154 - 150ms/epoch - 12ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01450
# 13/13 - 0s - loss: 0.0150 - 144ms/epoch - 11ms/step
# Epoch 55/80
#
# Epoch 55: loss improved from 0.01450 to 0.01428, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0143 - 180ms/epoch - 14ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.01428
# 13/13 - 0s - loss: 0.0148 - 151ms/epoch - 12ms/step
# Epoch 57/80
#
# Epoch 57: loss improved from 0.01428 to 0.01387, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0139 - 170ms/epoch - 13ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.01387
# 13/13 - 0s - loss: 0.0143 - 144ms/epoch - 11ms/step
# Epoch 59/80
#
# Epoch 59: loss improved from 0.01387 to 0.01338, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0134 - 195ms/epoch - 15ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01338
# 13/13 - 0s - loss: 0.0142 - 177ms/epoch - 14ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01338
# 13/13 - 0s - loss: 0.0148 - 148ms/epoch - 11ms/step
# Epoch 62/80
#
# Epoch 62: loss improved from 0.01338 to 0.01293, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0129 - 183ms/epoch - 14ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01293
# 13/13 - 0s - loss: 0.0140 - 146ms/epoch - 11ms/step
# Epoch 64/80
#
# Epoch 64: loss improved from 0.01293 to 0.01290, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0129 - 174ms/epoch - 13ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01290
# 13/13 - 0s - loss: 0.0134 - 147ms/epoch - 11ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01290
# 13/13 - 0s - loss: 0.0131 - 163ms/epoch - 13ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01290
# 13/13 - 0s - loss: 0.0140 - 151ms/epoch - 12ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01290
# 13/13 - 0s - loss: 0.0146 - 159ms/epoch - 12ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01290
# 13/13 - 0s - loss: 0.0130 - 167ms/epoch - 13ms/step
# Epoch 70/80
#
# Epoch 70: loss improved from 0.01290 to 0.01274, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0127 - 172ms/epoch - 13ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01274
# 13/13 - 0s - loss: 0.0137 - 157ms/epoch - 12ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01274
# 13/13 - 0s - loss: 0.0135 - 142ms/epoch - 11ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01274
# 13/13 - 0s - loss: 0.0142 - 146ms/epoch - 11ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01274
# 13/13 - 0s - loss: 0.0149 - 154ms/epoch - 12ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01274
# 13/13 - 0s - loss: 0.0131 - 218ms/epoch - 17ms/step
# Epoch 76/80
#
# Epoch 76: loss improved from 0.01274 to 0.01220, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0122 - 264ms/epoch - 20ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01220
# 13/13 - 0s - loss: 0.0133 - 419ms/epoch - 32ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01220
# 13/13 - 0s - loss: 0.0137 - 237ms/epoch - 18ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01220
# 13/13 - 0s - loss: 0.0136 - 237ms/epoch - 18ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01220
# 13/13 - 0s - loss: 0.0134 - 309ms/epoch - 24ms/step

# %%
# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_5_3_2.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 21/21 [==============================] - 1s 3ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 13/13 [==============================] - 0s 5ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 5ms/step

# %%
# Dự báo dữ liệu test, val
train_predict=model.predict(x_train)
y_pred=model.predict(x_test)
y_pred_val=model.predict(x_val)

# Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=sc.inverse_transform(train_predict)
y_pred=sc.inverse_transform(y_pred)
y_pred_val=sc.inverse_transform(y_pred_val)
# Out:
# 21/21 [==============================] - 2s 5ms/step
# 13/13 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 4ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 5:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 5)
# [0.9419471425344477, 0.9085159250056472, 0.8998192907160605, 0.8724870115202168, 0.8975604246668172]

# %%
# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.891803503036499], [0.8820953965187073], [0.8706755638122559], [0.8595760464668274], [0.8495618104934692], [0.8398889899253845], [0.8303122520446777], [0.8207433223724365], [0.8111986517906189], [0.8017092347145081], [0.7922854423522949], [0.7829272747039795], [0.7736316323280334], [0.7643958330154419], [0.7552189230918884], [0.7461003065109253], [0.7370391488075256], [0.7280347943305969], [0.719086766242981], [0.7101946473121643], [0.7013579607009888], [0.6925762295722961], [0.6838492751121521], [0.6751766204833984], [0.666558027267456], [0.6579932570457458], [0.6494821310043335], [0.6410244703292847], [0.632620096206665], [0.6242689490318298]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[1973.60282159]
#  [1965.00726408]
#  [1954.8961442 ]
#  [1945.06863154]
#  [1936.20202701]
#  [1927.63771168]
#  [1919.15846796]
#  [1910.68613763]
#  [1902.2352863 ]
#  [1893.83335642]
#  [1885.48953066]
#  [1877.20380902]
#  [1868.97344726]
#  [1860.79607055]
#  [1852.67083451]
#  [1844.59721138]
#  [1836.57446235]
#  [1828.6020069 ]
#  [1820.67942283]
#  [1812.80634073]
#  [1804.9823384 ]
#  [1797.20699366]
#  [1789.48014818]
#  [1781.80137978]
#  [1774.17047734]
#  [1766.58722979]
#  [1759.05147879]
#  [1751.56306603]
#  [1744.12183318]
#  [1736.72772747]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  13.33383027696118
# MAPE:  0.7274541272746113
# RMSE:  17.977753761470762
#
# ** Validate **
# MAE:  13.345687913161054
# MAPE:  0.7295854154123173
# RMSE:  17.866123788124433

# %% [markdown]
# # Evaluate Model
#
# ---
#
# ![image.png](data:image/png;base64,...)
