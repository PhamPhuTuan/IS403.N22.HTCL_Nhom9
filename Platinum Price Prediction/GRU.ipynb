# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow --quiet

# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import libraries for working with dates and times
import datetime as dt

# Import TensorFlow and Keras libraries for building and training neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, Reshape, Flatten, GRU
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

# Import scikit-learn library for various metrics and preprocessing tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Import matplotlib library for creating plots and charts
import matplotlib.pyplot as plt

# Magic command to display plots inline in the Jupyter Notebook
# %matplotlib inline

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# Read in the Platinum dataset from a CSV file
df=pd.read_csv("/content/drive/MyDrive/PTDLKD/Data/Platinum_Data.csv")
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %% [markdown]
# # Preprocessing Data
#
# ---

# %%
# Format column Date
df.index = pd.to_datetime(df.index,format='%m/%d/%Y')

# Format column Price to float
df['Price'] = df.Price.str.replace(',','').astype(float)

# Flip the column
df = df.iloc[::-1]

# Create new Dataframe
df1 = pd.DataFrame(df, columns=['Date', 'Price'])
df1.drop('Date', axis = 1, inplace = True)

# Plot the 'price' column of the 'df' DataFrame
plt.figure(figsize=(16,5))
plt.plot(df1['Price'])
plt.title('Prices of Platinum')
plt.show()

# %% [markdown]
# # Split dataset (7-2-1)
#
# ---

# %%
# Create a MinMaxScaler object with a specified range
data = df1.values
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)

# Split the data
train_size = int(0.7 * len(sc_train))
test_size = int(0.2 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an GRU layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an GRU layer with 50 units
model.add(GRU(50,return_sequences=True))

# Add an GRU layer with 50 units
model.add(GRU(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_7_2_1.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.13182, saving model to save_model_7_2_1.hdf5
# 22/22 - 15s - loss: 0.1318 - 15s/epoch - 664ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.13182 to 0.04324, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0432 - 579ms/epoch - 26ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.04324 to 0.03034, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0303 - 806ms/epoch - 37ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03034 to 0.02728, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0273 - 832ms/epoch - 38ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02728 to 0.02484, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0248 - 866ms/epoch - 39ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.02484 to 0.02468, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0247 - 1s/epoch - 46ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.02468 to 0.02444, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0244 - 898ms/epoch - 41ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.02444
# 22/22 - 1s - loss: 0.0254 - 695ms/epoch - 32ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.02444
# 22/22 - 1s - loss: 0.0247 - 803ms/epoch - 37ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.02444
# 22/22 - 1s - loss: 0.0260 - 1s/epoch - 52ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.02444 to 0.02367, saving model to save_model_7_2_1.hdf5
# 22/22 - 2s - loss: 0.0237 - 2s/epoch - 79ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.02367
# 22/22 - 1s - loss: 0.0242 - 1s/epoch - 63ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.02367
# 22/22 - 1s - loss: 0.0258 - 877ms/epoch - 40ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.02367
# 22/22 - 1s - loss: 0.0248 - 903ms/epoch - 41ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.02367 to 0.02305, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0231 - 628ms/epoch - 29ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.02305
# 22/22 - 1s - loss: 0.0238 - 653ms/epoch - 30ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.02305 to 0.02247, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0225 - 837ms/epoch - 38ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.02247 to 0.02221, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0222 - 905ms/epoch - 41ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.02221
# 22/22 - 1s - loss: 0.0247 - 702ms/epoch - 32ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.02221
# 22/22 - 1s - loss: 0.0264 - 788ms/epoch - 36ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.02221 to 0.02086, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0209 - 796ms/epoch - 36ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.02086 to 0.02074, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0207 - 973ms/epoch - 44ms/step
# Epoch 23/80
#
# Epoch 23: loss improved from 0.02074 to 0.02054, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0205 - 948ms/epoch - 43ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.02054
# 22/22 - 1s - loss: 0.0228 - 733ms/epoch - 33ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.02054 to 0.01996, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0200 - 853ms/epoch - 39ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.01996 to 0.01910, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0191 - 1s/epoch - 66ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.01910
# 22/22 - 1s - loss: 0.0192 - 1s/epoch - 65ms/step
# Epoch 28/80
#
# Epoch 28: loss improved from 0.01910 to 0.01879, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0188 - 1s/epoch - 67ms/step
# Epoch 29/80
#
# Epoch 29: loss improved from 0.01879 to 0.01795, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0180 - 1s/epoch - 48ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.01795
# 22/22 - 1s - loss: 0.0186 - 825ms/epoch - 37ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.01795 to 0.01763, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0176 - 692ms/epoch - 31ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.01763 to 0.01724, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0172 - 618ms/epoch - 28ms/step
# Epoch 33/80
#
# Epoch 33: loss improved from 0.01724 to 0.01684, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0168 - 692ms/epoch - 31ms/step
# Epoch 34/80
#
# Epoch 34: loss improved from 0.01684 to 0.01649, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0165 - 625ms/epoch - 28ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.01649
# 22/22 - 1s - loss: 0.0172 - 519ms/epoch - 24ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.01649
# 22/22 - 1s - loss: 0.0172 - 535ms/epoch - 24ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01649
# 22/22 - 1s - loss: 0.0166 - 577ms/epoch - 26ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01649
# 22/22 - 1s - loss: 0.0180 - 745ms/epoch - 34ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01649
# 22/22 - 0s - loss: 0.0177 - 306ms/epoch - 14ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.01649
# 22/22 - 0s - loss: 0.0166 - 323ms/epoch - 15ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01649
# 22/22 - 0s - loss: 0.0180 - 294ms/epoch - 13ms/step
# Epoch 42/80
#
# Epoch 42: loss improved from 0.01649 to 0.01612, saving model to save_model_7_2_1.hdf5
# 22/22 - 0s - loss: 0.0161 - 332ms/epoch - 15ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0182 - 309ms/epoch - 14ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0165 - 301ms/epoch - 14ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0173 - 307ms/epoch - 14ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0175 - 286ms/epoch - 13ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0176 - 297ms/epoch - 13ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0190 - 326ms/epoch - 15ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0168 - 287ms/epoch - 13ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01612
# 22/22 - 0s - loss: 0.0170 - 428ms/epoch - 19ms/step
# Epoch 51/80
#
# Epoch 51: loss improved from 0.01612 to 0.01607, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0161 - 518ms/epoch - 24ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01607
# 22/22 - 0s - loss: 0.0166 - 489ms/epoch - 22ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01607
# 22/22 - 0s - loss: 0.0190 - 492ms/epoch - 22ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01607
# 22/22 - 0s - loss: 0.0168 - 499ms/epoch - 23ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01607
# 22/22 - 0s - loss: 0.0164 - 482ms/epoch - 22ms/step
# Epoch 56/80
#
# Epoch 56: loss improved from 0.01607 to 0.01585, saving model to save_model_7_2_1.hdf5
# 22/22 - 1s - loss: 0.0159 - 525ms/epoch - 24ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.01585
# 22/22 - 1s - loss: 0.0164 - 503ms/epoch - 23ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.01585
# 22/22 - 1s - loss: 0.0161 - 662ms/epoch - 30ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0162 - 420ms/epoch - 19ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0164 - 366ms/epoch - 17ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0168 - 363ms/epoch - 17ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0164 - 366ms/epoch - 17ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0161 - 327ms/epoch - 15ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0162 - 312ms/epoch - 14ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0166 - 387ms/epoch - 18ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0171 - 307ms/epoch - 14ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0185 - 306ms/epoch - 14ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0168 - 333ms/epoch - 15ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0168 - 316ms/epoch - 14ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0163 - 298ms/epoch - 14ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0170 - 323ms/epoch - 15ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0179 - 283ms/epoch - 13ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0199 - 288ms/epoch - 13ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0162 - 308ms/epoch - 14ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0164 - 335ms/epoch - 15ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0190 - 320ms/epoch - 15ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0175 - 313ms/epoch - 14ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0165 - 356ms/epoch - 16ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0170 - 303ms/epoch - 14ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01585
# 22/22 - 0s - loss: 0.0175 - 312ms/epoch - 14ms/step

# %%
# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_7_2_1.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 34/34 [==============================] - 1s 4ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 10/10 [==============================] - 0s 4ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 5ms/step

# %%
# Dự báo dữ liệu test, val
train_predict=model.predict(x_train)
y_pred=model.predict(x_test)
y_pred_val=model.predict(x_val)

# Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=sc.inverse_transform(train_predict)
y_pred=sc.inverse_transform(y_pred)
y_pred_val=sc.inverse_transform(y_pred_val)
# Out:
# 34/34 [==============================] - 1s 4ms/step
# 10/10 [==============================] - 0s 6ms/step
# 5/5 [==============================] - 0s 6ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 5:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 5)
# [0.6738995231842996, 0.6631193421325409, 0.6848179116854399, 0.6510952940363485, 0.6752815976781147]

# %%
# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.6834724545478821], [0.6920198202133179], [0.6988139152526855], [0.7048361897468567], [0.7114260792732239], [0.7183010578155518], [0.7253968715667725], [0.7325906753540039], [0.7398532629013062], [0.747201144695282], [0.7546497583389282], [0.7622079253196716], [0.769877552986145], [0.7776584625244141], [0.7855510711669922], [0.7935566902160645], [0.8016765117645264], [0.809912383556366], [0.8182656764984131], [0.8267375230789185], [0.8353290557861328], [0.844041109085083], [0.852874755859375], [0.8618305325508118], [0.8709089756011963], [0.8801103234291077], [0.8894350528717041], [0.898883044719696], [0.9084540009498596], [0.918147623538971]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['Date'].astype(str).tolist()

# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%m/%d/%Y').date() for date in datelist_train]

# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[1089.72649449]
#  [1095.91094092]
#  [1100.82680838]
#  [1105.18422509]
#  [1109.95233966]
#  [1114.92673038]
#  [1120.06090642]
#  [1125.26598315]
#  [1130.52082837]
#  [1135.83738824]
#  [1141.22683265]
#  [1146.69554437]
#  [1152.24490346]
#  [1157.87478056]
#  [1163.58547754]
#  [1169.37794321]
#  [1175.25304009]
#  [1181.21210512]
#  [1187.25613023]
#  [1193.38593482]
#  [1199.60233831]
#  [1205.90594448]
#  [1212.2975296 ]
#  [1218.77748183]
#  [1225.3461893 ]
#  [1232.00382452]
#  [1238.75073251]
#  [1245.58682701]
#  [1252.51189239]
#  [1259.52571301]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  15.123048876796124
# MAPE:  1.5751579047011264
# RMSE:  19.351034920234913
#
# ** Validate **
# MAE:  15.464889157046176
# MAPE:  1.50916481693982
# RMSE:  19.661289063056955

# %% [markdown]
# # Split dataset (6-3-1)
#
# ---

# %%
# Split the data
train_size = int(0.6 * len(sc_train))
test_size = int(0.3 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an GRU layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an GRU layer with 50 units
model.add(GRU(50,return_sequences=True))

# Add an GRU layer with 50 units
model.add(GRU(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_6_3_1.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.16679, saving model to save_model_6_3_1.hdf5
# 19/19 - 8s - loss: 0.1668 - 8s/epoch - 428ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.16679 to 0.06616, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0662 - 297ms/epoch - 16ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.06616 to 0.03391, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0339 - 297ms/epoch - 16ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03391 to 0.02771, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0277 - 276ms/epoch - 15ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02771 to 0.02515, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0251 - 306ms/epoch - 16ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.02515 to 0.02398, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0240 - 279ms/epoch - 15ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.02398 to 0.02383, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0238 - 302ms/epoch - 16ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.02383 to 0.02366, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0237 - 290ms/epoch - 15ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.02366
# 19/19 - 0s - loss: 0.0241 - 248ms/epoch - 13ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.02366
# 19/19 - 0s - loss: 0.0241 - 260ms/epoch - 14ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.02366
# 19/19 - 0s - loss: 0.0244 - 265ms/epoch - 14ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.02366
# 19/19 - 0s - loss: 0.0241 - 262ms/epoch - 14ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.02366 to 0.02290, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0229 - 281ms/epoch - 15ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.02290
# 19/19 - 0s - loss: 0.0245 - 280ms/epoch - 15ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.02290 to 0.02234, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0223 - 286ms/epoch - 15ms/step
# Epoch 16/80
#
# Epoch 16: loss improved from 0.02234 to 0.02203, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0220 - 288ms/epoch - 15ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.02203
# 19/19 - 0s - loss: 0.0221 - 257ms/epoch - 14ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.02203
# 19/19 - 1s - loss: 0.0246 - 617ms/epoch - 32ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.02203 to 0.02103, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0210 - 445ms/epoch - 23ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.02103
# 19/19 - 0s - loss: 0.0247 - 285ms/epoch - 15ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.02103
# 19/19 - 0s - loss: 0.0215 - 269ms/epoch - 14ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.02103
# 19/19 - 0s - loss: 0.0216 - 261ms/epoch - 14ms/step
# Epoch 23/80
#
# Epoch 23: loss improved from 0.02103 to 0.02082, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0208 - 303ms/epoch - 16ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.02082
# 19/19 - 0s - loss: 0.0213 - 257ms/epoch - 14ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.02082
# 19/19 - 0s - loss: 0.0219 - 253ms/epoch - 13ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02082
# 19/19 - 0s - loss: 0.0229 - 259ms/epoch - 14ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02082
# 19/19 - 0s - loss: 0.0209 - 271ms/epoch - 14ms/step
# Epoch 28/80
#
# Epoch 28: loss improved from 0.02082 to 0.01863, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0186 - 411ms/epoch - 22ms/step
# Epoch 29/80
#
# Epoch 29: loss improved from 0.01863 to 0.01790, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0179 - 452ms/epoch - 24ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.01790
# 19/19 - 0s - loss: 0.0189 - 427ms/epoch - 22ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.01790 to 0.01733, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0173 - 475ms/epoch - 25ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.01733 to 0.01708, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0171 - 466ms/epoch - 25ms/step
# Epoch 33/80
#
# Epoch 33: loss improved from 0.01708 to 0.01663, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0166 - 469ms/epoch - 25ms/step
# Epoch 34/80
#
# Epoch 34: loss improved from 0.01663 to 0.01648, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0165 - 454ms/epoch - 24ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.01648 to 0.01591, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0159 - 452ms/epoch - 24ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0161 - 410ms/epoch - 22ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0159 - 401ms/epoch - 21ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0165 - 288ms/epoch - 15ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0161 - 252ms/epoch - 13ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0166 - 268ms/epoch - 14ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0164 - 262ms/epoch - 14ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0177 - 247ms/epoch - 13ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0165 - 259ms/epoch - 14ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0167 - 263ms/epoch - 14ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0164 - 287ms/epoch - 15ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0165 - 276ms/epoch - 15ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0170 - 274ms/epoch - 14ms/step
# Epoch 48/80
#
# Epoch 48: loss improved from 0.01591 to 0.01571, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0157 - 290ms/epoch - 15ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01571
# 19/19 - 0s - loss: 0.0160 - 273ms/epoch - 14ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01571
# 19/19 - 0s - loss: 0.0162 - 253ms/epoch - 13ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.01571
# 19/19 - 0s - loss: 0.0175 - 264ms/epoch - 14ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01571
# 19/19 - 0s - loss: 0.0177 - 256ms/epoch - 13ms/step
# Epoch 53/80
#
# Epoch 53: loss improved from 0.01571 to 0.01562, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0156 - 306ms/epoch - 16ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01562
# 19/19 - 0s - loss: 0.0167 - 255ms/epoch - 13ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01562
# 19/19 - 0s - loss: 0.0166 - 272ms/epoch - 14ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.01562
# 19/19 - 0s - loss: 0.0163 - 257ms/epoch - 14ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.01562
# 19/19 - 0s - loss: 0.0160 - 262ms/epoch - 14ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.01562
# 19/19 - 0s - loss: 0.0168 - 248ms/epoch - 13ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01562
# 19/19 - 0s - loss: 0.0168 - 263ms/epoch - 14ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01562
# 19/19 - 0s - loss: 0.0157 - 260ms/epoch - 14ms/step
# Epoch 61/80
#
# Epoch 61: loss improved from 0.01562 to 0.01541, saving model to save_model_6_3_1.hdf5
# 19/19 - 0s - loss: 0.0154 - 286ms/epoch - 15ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0163 - 257ms/epoch - 14ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0164 - 271ms/epoch - 14ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0161 - 276ms/epoch - 15ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0167 - 250ms/epoch - 13ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0195 - 260ms/epoch - 14ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0184 - 252ms/epoch - 13ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0163 - 249ms/epoch - 13ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0157 - 264ms/epoch - 14ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0179 - 268ms/epoch - 14ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0167 - 255ms/epoch - 13ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0159 - 257ms/epoch - 14ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0168 - 253ms/epoch - 13ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0160 - 268ms/epoch - 14ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0163 - 365ms/epoch - 19ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0167 - 407ms/epoch - 21ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0180 - 438ms/epoch - 23ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0160 - 411ms/epoch - 22ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0165 - 415ms/epoch - 22ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01541
# 19/19 - 0s - loss: 0.0164 - 401ms/epoch - 21ms/step

# %%
# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_6_3_1.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 30/30 [==============================] - 1s 4ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 15/15 [==============================] - 0s 4ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 5ms/step

# %%
# Dự báo dữ liệu test, val
train_predict=model.predict(x_train)
y_pred=model.predict(x_test)
y_pred_val=model.predict(x_val)

# Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=sc.inverse_transform(train_predict)
y_pred=sc.inverse_transform(y_pred)
y_pred_val=sc.inverse_transform(y_pred_val)
# Out:
# 30/30 [==============================] - 1s 4ms/step
# 15/15 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 5ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 5:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 5)
# [0.6738995231842996, 0.6631193421325409, 0.6848179116854399, 0.6510952940363485, 0.6752815976781147]

# %%
# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.6744773983955383], [0.6734287738800049], [0.6711570024490356], [0.6684249043464661], [0.6661733984947205], [0.6639654636383057], [0.661759078502655], [0.6594940423965454], [0.6571606397628784], [0.6547686457633972], [0.6523211598396301], [0.6498192548751831], [0.6472618579864502], [0.6446477174758911], [0.6419757008552551], [0.639244794845581], [0.6364540457725525], [0.6336025595664978], [0.6306894421577454], [0.6277138590812683], [0.6246747970581055], [0.6215712428092957], [0.6184026002883911], [0.6151678562164307], [0.6118662357330322], [0.6084968447685242], [0.605059027671814], [0.60155189037323], [0.5979748368263245], [0.5943270921707153]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[1083.21812161]
#  [1082.45938934]
#  [1080.81564912]
#  [1078.83883954]
#  [1077.20976248]
#  [1075.61221122]
#  [1074.01578125]
#  [1072.37691438]
#  [1070.6885809 ]
#  [1068.95785364]
#  [1067.1869752 ]
#  [1065.37672186]
#  [1063.52631735]
#  [1061.63485598]
#  [1059.70151835]
#  [1057.72557131]
#  [1055.70632482]
#  [1053.64313197]
#  [1051.53534587]
#  [1049.38236274]
#  [1047.18344941]
#  [1044.93787273]
#  [1042.64520144]
#  [1040.30470237]
#  [1037.91581486]
#  [1035.47789203]
#  [1032.99045947]
#  [1030.45287028]
#  [1027.86469319]
#  [1025.22536754]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  14.039898145785937
# MAPE:  1.4277723896486108
# RMSE:  18.591522619507845
#
# ** Validate **
# MAE:  13.75681261196258
# MAPE:  1.3487938795756298
# RMSE:  17.892900453498747

# %% [markdown]
# # Split dataset (5-3-2)
#
# ---

# %%
# Split the data
train_size = int(0.5 * len(sc_train))
test_size = int(0.3 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an GRU layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an GRU layer with 50 units
model.add(GRU(50,return_sequences=True))

# Add an GRU layer with 50 units
model.add(GRU(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_5_3_2.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.12081, saving model to save_model_5_3_2.hdf5
# 16/16 - 8s - loss: 0.1208 - 8s/epoch - 489ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.12081 to 0.04590, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0459 - 248ms/epoch - 15ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.04590 to 0.03255, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0325 - 256ms/epoch - 16ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03255 to 0.02535, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0254 - 246ms/epoch - 15ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02535 to 0.02288, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0229 - 256ms/epoch - 16ms/step
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.02288
# 16/16 - 0s - loss: 0.0232 - 209ms/epoch - 13ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.02288 to 0.02232, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0223 - 247ms/epoch - 15ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.02232 to 0.02204, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0220 - 232ms/epoch - 14ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.02204 to 0.02169, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0217 - 262ms/epoch - 16ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.02169 to 0.02110, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0211 - 250ms/epoch - 16ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.02110
# 16/16 - 0s - loss: 0.0223 - 217ms/epoch - 14ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.02110
# 16/16 - 0s - loss: 0.0221 - 212ms/epoch - 13ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.02110
# 16/16 - 0s - loss: 0.0229 - 211ms/epoch - 13ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.02110
# 16/16 - 0s - loss: 0.0225 - 223ms/epoch - 14ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.02110
# 16/16 - 0s - loss: 0.0213 - 230ms/epoch - 14ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.02110
# 16/16 - 0s - loss: 0.0216 - 215ms/epoch - 13ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.02110 to 0.02033, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0203 - 252ms/epoch - 16ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.02033
# 16/16 - 0s - loss: 0.0209 - 220ms/epoch - 14ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.02033
# 16/16 - 0s - loss: 0.0208 - 238ms/epoch - 15ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.02033
# 16/16 - 0s - loss: 0.0214 - 206ms/epoch - 13ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.02033 to 0.02005, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0200 - 251ms/epoch - 16ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.02005 to 0.01987, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0199 - 248ms/epoch - 16ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.01987
# 16/16 - 0s - loss: 0.0200 - 229ms/epoch - 14ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.01987 to 0.01987, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0199 - 237ms/epoch - 15ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.01987 to 0.01919, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0192 - 235ms/epoch - 15ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.01919 to 0.01834, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0183 - 233ms/epoch - 15ms/step
# Epoch 27/80
#
# Epoch 27: loss improved from 0.01834 to 0.01834, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0183 - 255ms/epoch - 16ms/step
# Epoch 28/80
#
# Epoch 28: loss improved from 0.01834 to 0.01795, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0179 - 251ms/epoch - 16ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.01795
# 16/16 - 0s - loss: 0.0181 - 221ms/epoch - 14ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.01795
# 16/16 - 0s - loss: 0.0180 - 212ms/epoch - 13ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.01795 to 0.01690, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0169 - 259ms/epoch - 16ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.01690
# 16/16 - 0s - loss: 0.0182 - 278ms/epoch - 17ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.01690
# 16/16 - 0s - loss: 0.0176 - 345ms/epoch - 22ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.01690
# 16/16 - 0s - loss: 0.0179 - 341ms/epoch - 21ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.01690
# 16/16 - 0s - loss: 0.0195 - 356ms/epoch - 22ms/step
# Epoch 36/80
#
# Epoch 36: loss improved from 0.01690 to 0.01683, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0168 - 382ms/epoch - 24ms/step
# Epoch 37/80
#
# Epoch 37: loss improved from 0.01683 to 0.01557, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0156 - 401ms/epoch - 25ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01557
# 16/16 - 0s - loss: 0.0164 - 345ms/epoch - 22ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.01557 to 0.01530, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0153 - 382ms/epoch - 24ms/step
# Epoch 40/80
#
# Epoch 40: loss improved from 0.01530 to 0.01496, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0150 - 399ms/epoch - 25ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01496
# 16/16 - 0s - loss: 0.0168 - 324ms/epoch - 20ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.01496
# 16/16 - 0s - loss: 0.0154 - 332ms/epoch - 21ms/step
# Epoch 43/80
#
# Epoch 43: loss improved from 0.01496 to 0.01451, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0145 - 389ms/epoch - 24ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0147 - 328ms/epoch - 21ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0146 - 217ms/epoch - 14ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0149 - 236ms/epoch - 15ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0158 - 217ms/epoch - 14ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0153 - 205ms/epoch - 13ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0159 - 213ms/epoch - 13ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0146 - 221ms/epoch - 14ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0148 - 226ms/epoch - 14ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0153 - 209ms/epoch - 13ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0146 - 212ms/epoch - 13ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0148 - 235ms/epoch - 15ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01451
# 16/16 - 0s - loss: 0.0148 - 228ms/epoch - 14ms/step
# Epoch 56/80
#
# Epoch 56: loss improved from 0.01451 to 0.01398, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0140 - 257ms/epoch - 16ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0148 - 210ms/epoch - 13ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0143 - 210ms/epoch - 13ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0144 - 216ms/epoch - 14ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0140 - 226ms/epoch - 14ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0170 - 203ms/epoch - 13ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0175 - 216ms/epoch - 14ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0163 - 212ms/epoch - 13ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0160 - 221ms/epoch - 14ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0149 - 229ms/epoch - 14ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0142 - 207ms/epoch - 13ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0146 - 221ms/epoch - 14ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0151 - 220ms/epoch - 14ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0150 - 228ms/epoch - 14ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0143 - 209ms/epoch - 13ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0141 - 216ms/epoch - 13ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01398
# 16/16 - 0s - loss: 0.0145 - 212ms/epoch - 13ms/step
# Epoch 73/80
#
# Epoch 73: loss improved from 0.01398 to 0.01383, saving model to save_model_5_3_2.hdf5
# 16/16 - 0s - loss: 0.0138 - 243ms/epoch - 15ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01383
# 16/16 - 0s - loss: 0.0164 - 226ms/epoch - 14ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01383
# 16/16 - 0s - loss: 0.0152 - 207ms/epoch - 13ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01383
# 16/16 - 0s - loss: 0.0141 - 204ms/epoch - 13ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01383
# 16/16 - 0s - loss: 0.0143 - 217ms/epoch - 14ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01383
# 16/16 - 0s - loss: 0.0142 - 230ms/epoch - 14ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01383
# 16/16 - 0s - loss: 0.0144 - 219ms/epoch - 14ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01383
# 16/16 - 0s - loss: 0.0154 - 216ms/epoch - 13ms/step

# %%
# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_5_3_2.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 25/25 [==============================] - 2s 4ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 15/15 [==============================] - 0s 5ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 10/10 [==============================] - 0s 4ms/step

# %%
# Dự báo dữ liệu test, val
train_predict=model.predict(x_train)
y_pred=model.predict(x_test)
y_pred_val=model.predict(x_val)

# Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=sc.inverse_transform(train_predict)
y_pred=sc.inverse_transform(y_pred)
y_pred_val=sc.inverse_transform(y_pred_val)
# Out:
# 25/25 [==============================] - 1s 4ms/step
# 15/15 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 4ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 5:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 5)
# [0.6738995231842996, 0.6631193421325409, 0.6848179116854399, 0.6510952940363485, 0.6752815976781147]

# %%
# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.6905372738838196], [0.699805736541748], [0.7085952758789062], [0.7171521782875061], [0.7260866165161133], [0.7353748083114624], [0.744858980178833], [0.7544968128204346], [0.7642908096313477], [0.7742553353309631], [0.7844038605690002], [0.794745683670044], [0.8052880167961121], [0.8160386681556702], [0.827005922794342], [0.8381985425949097], [0.8496254682540894], [0.8612960577011108], [0.8732202649116516], [0.8854077458381653], [0.8978687524795532], [0.9106139540672302], [0.9236540794372559], [0.9370000958442688], [0.9506634473800659], [0.9646558165550232], [0.9789890646934509], [0.993675172328949], [1.0087260007858276], [1.0241533517837524]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[1094.83824452]
#  [1101.54444067]
#  [1107.90411186]
#  [1114.0954586 ]
#  [1120.55997138]
#  [1127.28044255]
#  [1134.14271511]
#  [1141.11616892]
#  [1148.20261531]
#  [1155.41244788]
#  [1162.75541331]
#  [1170.23823942]
#  [1177.86614455]
#  [1185.64477834]
#  [1193.58013544]
#  [1201.67855549]
#  [1209.94650756]
#  [1218.39076255]
#  [1227.01852268]
#  [1235.8367745 ]
#  [1244.85293586]
#  [1254.07472647]
#  [1263.50990918]
#  [1273.16641935]
#  [1283.05253735]
#  [1293.17671607]
#  [1303.54753776]
#  [1314.17367094]
#  [1325.06369787]
#  [1336.22615768]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  18.25972811517164
# MAPE:  1.7080772651931544
# RMSE:  22.835701652580028
#
# ** Validate **
# MAE:  15.910253201998197
# MAPE:  1.64047350709541
# RMSE:  20.148370715056295

# %% [markdown]
# # Evaluate model
#
# ---
#
# ![image.png](data:image/png;base64,...)
