# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow --quiet

# %%
# !pip install keras-self-attention --quiet

# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import libraries for working with dates and times
import datetime as dt

# Import TensorFlow and Keras libraries for building and training neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, Reshape, Flatten
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

# Import scikit-learn library for various metrics and preprocessing tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Import matplotlib library for creating plots and charts
import matplotlib.pyplot as plt

# Magic command to display plots inline in the Jupyter Notebook
# %matplotlib inline

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# Read in the Silver dataset from a CSV file
df=pd.read_csv("/content/drive/MyDrive/PTDLKD/Data/Silver_Data.csv")
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %% [markdown]
# # Preprocessing Data
#
# ---

# %%
# Format column Date
df.index = pd.to_datetime(df.index,format='%m/%d/%Y')

# Flip the column
df = df.iloc[::-1]

# Create new Dataframe
df1 = pd.DataFrame(df, columns=['Date', 'Price'])
df1.drop('Date', axis = 1, inplace = True)

# Plot the 'price' column of the 'df' DataFrame
plt.figure(figsize=(16,5))
plt.plot(df1['Price'])
plt.title('Prices of Silver')
plt.show()

# %% [markdown]
# # Split dataset (7-2-1)
#
# ---

# %%
# Convert the 'df1' DataFrame to a NumPy array
data = df1.values

# Split the data (7-2-1)
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create a MinMaxScaler object with a specified range
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
from keras.models import Model
from keras.layers import Dense, Input, SimpleRNN, Attention

input_seq = Input(shape=(5, 1))
rnn_output = SimpleRNN(50, return_sequences=True)(input_seq)
attention_output = Attention()([rnn_output, rnn_output])
reshaped_output = Reshape((-1,))(attention_output)
output = Dense(1)(reshaped_output)

model = Model(inputs=input_seq, outputs=output)
model.compile(loss='mean_squared_error', optimizer='adam')

save_model = 'save_model(7-2-1).hdf5'
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.01475, saving model to save_model(7-2-1).hdf5
# 18/18 - 3s - loss: 0.0148 - 3s/epoch - 168ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.01475 to 0.00198, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0020 - 355ms/epoch - 20ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.00198 to 0.00152, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0015 - 227ms/epoch - 13ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.00152 to 0.00133, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0013 - 159ms/epoch - 9ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.00133 to 0.00131, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0013 - 162ms/epoch - 9ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.00131 to 0.00130, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0013 - 268ms/epoch - 15ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.00130 to 0.00129, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0013 - 259ms/epoch - 14ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.00129 to 0.00128, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0013 - 225ms/epoch - 13ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.00128
# 18/18 - 0s - loss: 0.0013 - 145ms/epoch - 8ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.00128
# 18/18 - 0s - loss: 0.0013 - 207ms/epoch - 11ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.00128 to 0.00124, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0012 - 286ms/epoch - 16ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.00124
# 18/18 - 0s - loss: 0.0013 - 174ms/epoch - 10ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.00124
# 18/18 - 0s - loss: 0.0013 - 166ms/epoch - 9ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.00124
# 18/18 - 0s - loss: 0.0013 - 137ms/epoch - 8ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.00124 to 0.00123, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0012 - 268ms/epoch - 15ms/step
# Epoch 16/80
#
# Epoch 16: loss improved from 0.00123 to 0.00117, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0012 - 280ms/epoch - 16ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.00117 to 0.00116, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0012 - 269ms/epoch - 15ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.00116
# 18/18 - 0s - loss: 0.0012 - 166ms/epoch - 9ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.00116 to 0.00115, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0012 - 199ms/epoch - 11ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.00115
# 18/18 - 0s - loss: 0.0012 - 130ms/epoch - 7ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.00115
# 18/18 - 0s - loss: 0.0012 - 145ms/epoch - 8ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.00115 to 0.00110, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0011 - 210ms/epoch - 12ms/step
# Epoch 23/80
#
# Epoch 23: loss improved from 0.00110 to 0.00109, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0011 - 371ms/epoch - 21ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.00109 to 0.00106, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0011 - 374ms/epoch - 21ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.00106 to 0.00105, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0010 - 177ms/epoch - 10ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.00105 to 0.00103, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 0.0010 - 169ms/epoch - 9ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.00103
# 18/18 - 0s - loss: 0.0011 - 139ms/epoch - 8ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.00103
# 18/18 - 0s - loss: 0.0011 - 109ms/epoch - 6ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.00103
# 18/18 - 0s - loss: 0.0011 - 113ms/epoch - 6ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.00103
# 18/18 - 0s - loss: 0.0011 - 161ms/epoch - 9ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.00103 to 0.00096, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 9.6169e-04 - 143ms/epoch - 8ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.00096 to 0.00095, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 9.4630e-04 - 193ms/epoch - 11ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.00095
# 18/18 - 0s - loss: 0.0010 - 110ms/epoch - 6ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.00095
# 18/18 - 0s - loss: 0.0015 - 107ms/epoch - 6ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.00095
# 18/18 - 0s - loss: 0.0010 - 98ms/epoch - 5ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.00095
# 18/18 - 0s - loss: 0.0011 - 173ms/epoch - 10ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.00095
# 18/18 - 0s - loss: 0.0011 - 134ms/epoch - 7ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.00095
# 18/18 - 0s - loss: 0.0010 - 118ms/epoch - 7ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.00095 to 0.00094, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 9.3524e-04 - 180ms/epoch - 10ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.00094
# 18/18 - 0s - loss: 9.7622e-04 - 173ms/epoch - 10ms/step
# Epoch 41/80
#
# Epoch 41: loss improved from 0.00094 to 0.00093, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 9.3339e-04 - 161ms/epoch - 9ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.00093
# 18/18 - 0s - loss: 9.9572e-04 - 104ms/epoch - 6ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.00093
# 18/18 - 0s - loss: 0.0012 - 106ms/epoch - 6ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.00093
# 18/18 - 0s - loss: 0.0012 - 109ms/epoch - 6ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.00093
# 18/18 - 0s - loss: 0.0010 - 113ms/epoch - 6ms/step
# Epoch 46/80
#
# Epoch 46: loss improved from 0.00093 to 0.00091, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 9.0753e-04 - 163ms/epoch - 9ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.00091
# 18/18 - 0s - loss: 9.1876e-04 - 135ms/epoch - 7ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.00091
# 18/18 - 0s - loss: 9.2450e-04 - 114ms/epoch - 6ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.00091
# 18/18 - 0s - loss: 9.7594e-04 - 113ms/epoch - 6ms/step
# Epoch 50/80
#
# Epoch 50: loss improved from 0.00091 to 0.00087, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 8.6664e-04 - 132ms/epoch - 7ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.00087
# 18/18 - 0s - loss: 8.8550e-04 - 117ms/epoch - 7ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.00087
# 18/18 - 0s - loss: 0.0011 - 130ms/epoch - 7ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.00087
# 18/18 - 0s - loss: 9.4931e-04 - 124ms/epoch - 7ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.00087
# 18/18 - 0s - loss: 9.6531e-04 - 112ms/epoch - 6ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.00087
# 18/18 - 0s - loss: 9.5345e-04 - 114ms/epoch - 6ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.00087
# 18/18 - 0s - loss: 8.7706e-04 - 120ms/epoch - 7ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.00087
# 18/18 - 0s - loss: 8.6711e-04 - 106ms/epoch - 6ms/step
# Epoch 58/80
#
# Epoch 58: loss improved from 0.00087 to 0.00083, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 8.3365e-04 - 128ms/epoch - 7ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.00083
# 18/18 - 0s - loss: 8.5327e-04 - 121ms/epoch - 7ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.00083
# 18/18 - 0s - loss: 8.4101e-04 - 116ms/epoch - 6ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.00083
# 18/18 - 0s - loss: 8.3385e-04 - 136ms/epoch - 8ms/step
# Epoch 62/80
#
# Epoch 62: loss improved from 0.00083 to 0.00082, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 8.2378e-04 - 144ms/epoch - 8ms/step
# Epoch 63/80
#
# Epoch 63: loss improved from 0.00082 to 0.00082, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 8.1764e-04 - 138ms/epoch - 8ms/step
# Epoch 64/80
#
# Epoch 64: loss improved from 0.00082 to 0.00080, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 8.0250e-04 - 155ms/epoch - 9ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.4348e-04 - 135ms/epoch - 8ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.00080
# 18/18 - 0s - loss: 9.4209e-04 - 106ms/epoch - 6ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.8617e-04 - 114ms/epoch - 6ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.00080
# 18/18 - 0s - loss: 9.0866e-04 - 103ms/epoch - 6ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.00080
# 18/18 - 0s - loss: 9.0239e-04 - 107ms/epoch - 6ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.3280e-04 - 150ms/epoch - 8ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.2106e-04 - 149ms/epoch - 8ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.5898e-04 - 108ms/epoch - 6ms/step
# Epoch 73/80
#
# Epoch 73: loss improved from 0.00080 to 0.00080, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 7.9521e-04 - 123ms/epoch - 7ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.5617e-04 - 99ms/epoch - 6ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.4904e-04 - 103ms/epoch - 6ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.00080
# 18/18 - 0s - loss: 8.5158e-04 - 103ms/epoch - 6ms/step
# Epoch 77/80
#
# Epoch 77: loss improved from 0.00080 to 0.00078, saving model to save_model(7-2-1).hdf5
# 18/18 - 0s - loss: 7.7921e-04 - 137ms/epoch - 8ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.00078
# 18/18 - 0s - loss: 7.9992e-04 - 110ms/epoch - 6ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.00078
# 18/18 - 0s - loss: 8.1068e-04 - 111ms/epoch - 6ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.00078
# 18/18 - 0s - loss: 8.0101e-04 - 198ms/epoch - 11ms/step

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model(7-2-1).hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 1s 5ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 8/8 [==============================] - 0s 5ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[sc_train.shape[0]-5:].reshape(1, -1)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps,1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.6969286799430847], [0.7053027749061584], [0.7150203585624695], [0.715984582901001], [0.7240099310874939], [0.7293277978897095], [0.7356005907058716], [0.7430959939956665], [0.7487261295318604], [0.7554418444633484], [0.7614598274230957], [0.7674314975738525], [0.7736380696296692], [0.7794454097747803], [0.7853797078132629], [0.7911123037338257], [0.7967095971107483], [0.802237868309021], [0.8075774312019348], [0.812816321849823], [0.817901074886322], [0.8228342533111572], [0.8276256918907166], [0.8322527408599854], [0.836727499961853], [0.8410413861274719], [0.8451938033103943], [0.8491880297660828], [0.8530200719833374], [0.856693685054779]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['Date'].astype(str).tolist()

# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%m/%d/%Y').date() for date in datelist_train]

# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Silver Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  0.3987714737653733
# MAPE:  1.849775838512082
# RMSE:  0.5088078743835064
#
# ** Validate **
# MAE:  0.36827096438407886
# MAPE:  1.5925705265592067
# RMSE:  0.4739971383536376

# %% [markdown]
# # Split dataset (6-3-1)
#
# ---

# %%
# 4. Split data (6-3-1)
train_size = int(0.6 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 64 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(units=64, input_shape=(x_train.shape[1], 1), return_sequences=True,kernel_regularizer=l2(0.01)))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=True))

# Add a dropout layer with a rate of 0.5
model.add(Dropout(0.5))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=False))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_6_3_1.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.25131, saving model to save_model_6_3_1.hdf5
# 16/16 - 9s - loss: 0.2513 - 9s/epoch - 535ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.25131 to 0.11383, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.1138 - 281ms/epoch - 18ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.11383 to 0.06075, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0607 - 283ms/epoch - 18ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.06075 to 0.05190, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0519 - 266ms/epoch - 17ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.05190 to 0.04613, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0461 - 262ms/epoch - 16ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.04613 to 0.04307, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0431 - 264ms/epoch - 16ms/step
# Epoch 7/80
#
# Epoch 7: loss did not improve from 0.04307
# 16/16 - 0s - loss: 0.0438 - 243ms/epoch - 15ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.04307
# 16/16 - 0s - loss: 0.0434 - 232ms/epoch - 14ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.04307 to 0.04132, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0413 - 275ms/epoch - 17ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.04132 to 0.03971, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0397 - 261ms/epoch - 16ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.03971 to 0.03893, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0389 - 281ms/epoch - 18ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.03893 to 0.03766, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0377 - 275ms/epoch - 17ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.03766
# 16/16 - 0s - loss: 0.0383 - 227ms/epoch - 14ms/step
# Epoch 14/80
#
# Epoch 14: loss improved from 0.03766 to 0.03617, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0362 - 272ms/epoch - 17ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.03617 to 0.03611, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0361 - 277ms/epoch - 17ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.03611
# 16/16 - 0s - loss: 0.0405 - 237ms/epoch - 15ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.03611
# 16/16 - 0s - loss: 0.0374 - 237ms/epoch - 15ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.03611 to 0.03568, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0357 - 262ms/epoch - 16ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.03568 to 0.03407, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0341 - 285ms/epoch - 18ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.03407
# 16/16 - 0s - loss: 0.0348 - 246ms/epoch - 15ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.03407
# 16/16 - 0s - loss: 0.0355 - 228ms/epoch - 14ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.03407 to 0.03383, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0338 - 264ms/epoch - 16ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.03383
# 16/16 - 0s - loss: 0.0343 - 250ms/epoch - 16ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.03383
# 16/16 - 0s - loss: 0.0354 - 237ms/epoch - 15ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.03383 to 0.03302, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0330 - 263ms/epoch - 16ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.03302
# 16/16 - 0s - loss: 0.0347 - 229ms/epoch - 14ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.03302
# 16/16 - 0s - loss: 0.0340 - 262ms/epoch - 16ms/step
# Epoch 28/80
#
# Epoch 28: loss improved from 0.03302 to 0.03226, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0323 - 272ms/epoch - 17ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.03226
# 16/16 - 0s - loss: 0.0330 - 236ms/epoch - 15ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.03226 to 0.03170, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0317 - 265ms/epoch - 17ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.03170
# 16/16 - 0s - loss: 0.0324 - 248ms/epoch - 16ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.03170
# 16/16 - 0s - loss: 0.0337 - 234ms/epoch - 15ms/step
# Epoch 33/80
#
# Epoch 33: loss improved from 0.03170 to 0.03155, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0316 - 256ms/epoch - 16ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.03155
# 16/16 - 0s - loss: 0.0317 - 236ms/epoch - 15ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.03155
# 16/16 - 0s - loss: 0.0327 - 247ms/epoch - 15ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.03155
# 16/16 - 0s - loss: 0.0338 - 234ms/epoch - 15ms/step
# Epoch 37/80
#
# Epoch 37: loss improved from 0.03155 to 0.03068, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0307 - 278ms/epoch - 17ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.03068
# 16/16 - 0s - loss: 0.0311 - 235ms/epoch - 15ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.03068
# 16/16 - 0s - loss: 0.0342 - 350ms/epoch - 22ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.03068
# 16/16 - 0s - loss: 0.0347 - 370ms/epoch - 23ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.03068
# 16/16 - 0s - loss: 0.0340 - 379ms/epoch - 24ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.03068
# 16/16 - 0s - loss: 0.0317 - 378ms/epoch - 24ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.03068
# 16/16 - 0s - loss: 0.0319 - 367ms/epoch - 23ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.03068 to 0.02931, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0293 - 451ms/epoch - 28ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0312 - 388ms/epoch - 24ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0301 - 378ms/epoch - 24ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0333 - 368ms/epoch - 23ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0317 - 357ms/epoch - 22ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0306 - 383ms/epoch - 24ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0314 - 374ms/epoch - 23ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0314 - 272ms/epoch - 17ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0311 - 235ms/epoch - 15ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0321 - 252ms/epoch - 16ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0315 - 258ms/epoch - 16ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0316 - 236ms/epoch - 15ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0317 - 243ms/epoch - 15ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0311 - 247ms/epoch - 15ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0314 - 237ms/epoch - 15ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0310 - 227ms/epoch - 14ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0342 - 232ms/epoch - 15ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0328 - 231ms/epoch - 14ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0311 - 261ms/epoch - 16ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0330 - 231ms/epoch - 14ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0301 - 234ms/epoch - 15ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0326 - 247ms/epoch - 15ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0303 - 247ms/epoch - 15ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02931
# 16/16 - 0s - loss: 0.0297 - 224ms/epoch - 14ms/step
# Epoch 68/80
#
# Epoch 68: loss improved from 0.02931 to 0.02926, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0293 - 266ms/epoch - 17ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02926
# 16/16 - 0s - loss: 0.0301 - 244ms/epoch - 15ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02926
# 16/16 - 0s - loss: 0.0301 - 240ms/epoch - 15ms/step
# Epoch 71/80
#
# Epoch 71: loss improved from 0.02926 to 0.02914, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0291 - 270ms/epoch - 17ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02914
# 16/16 - 0s - loss: 0.0312 - 234ms/epoch - 15ms/step
# Epoch 73/80
#
# Epoch 73: loss improved from 0.02914 to 0.02843, saving model to save_model_6_3_1.hdf5
# 16/16 - 0s - loss: 0.0284 - 273ms/epoch - 17ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02843
# 16/16 - 0s - loss: 0.0305 - 243ms/epoch - 15ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02843
# 16/16 - 0s - loss: 0.0302 - 232ms/epoch - 14ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02843
# 16/16 - 0s - loss: 0.0318 - 229ms/epoch - 14ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02843
# 16/16 - 0s - loss: 0.0328 - 239ms/epoch - 15ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02843
# 16/16 - 0s - loss: 0.0322 - 236ms/epoch - 15ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02843
# 16/16 - 0s - loss: 0.0312 - 235ms/epoch - 15ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02843
# 16/16 - 0s - loss: 0.0288 - 245ms/epoch - 15ms/step

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_6_3_1.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 24/24 [==============================] - 1s 5ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 12/12 [==============================] - 0s 6ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 4/4 [==============================] - 0s 6ms/step

# %%
# Predict the next 30 days
x_input=sc_train[sc_train.shape[0]-5:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

lst_output=[]
n_steps=5
i=0
while(i<30):
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1

# Print the final list of predictions
print(lst_output)
# Out:
# [0.68890375]
# 6
# [0.68890375]
# 7
# [0.68890375]
# 8
# [0.68890375]
# 9
# [0.68890375]
# 10
# [0.68890375]
# 11
# [0.68890375]
# 12
# [0.68890375]
# 13
# [0.68890375]
# 14
# [0.68890375]
# 15
# [0.68890375]
# 16
# [0.68890375]
# 17
# [0.68890375]
# 18
# [0.68890375]
# 19
# [0.68890375]
# 20
# [0.68890375]
# 21
# [0.68890375]
# 22
# [0.68890375]
# 23
# [0.68890375]
# 24
# [0.68890375]
# 25
# [0.68890375]
# 26
# [0.68890375]
# 27
# [0.68890375]
# 28
# [0.68890375]
# 29
# [0.68890375]
# 30
# [0.68890375]
# 31
# [0.68890375]
# 32
# [0.68890375]
# 33
# [0.68890375]
# 34
# [0.68890375]
# 35
# [[0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052], [0.6889037489891052]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Silver Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  0.6517818750143052
# MAPE:  2.9476526820381146
# RMSE:  0.8428507948338149
#
# ** Validate **
# MAE:  0.5987945839166641
# MAPE:  2.6087043660600835
# RMSE:  0.7612200427655924

# %% [markdown]
# # Split dataset (5-3-2)
#
# ---

# %%
# 4. Split data
train_size = int(0.5 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 64 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(units=64, input_shape=(x_train.shape[1], 1), return_sequences=True,kernel_regularizer=l2(0.01)))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=True))

# Add a dropout layer with a rate of 0.5
model.add(Dropout(0.5))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=False))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_5_3_2.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.21119, saving model to save_model_5_3_2.hdf5
# 13/13 - 7s - loss: 0.2112 - 7s/epoch - 504ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.21119 to 0.11264, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.1126 - 213ms/epoch - 16ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.11264 to 0.06959, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0696 - 215ms/epoch - 17ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.06959 to 0.04789, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0479 - 227ms/epoch - 17ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.04789 to 0.04296, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0430 - 228ms/epoch - 18ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.04296 to 0.04285, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0429 - 230ms/epoch - 18ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.04285 to 0.04050, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0405 - 231ms/epoch - 18ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.04050 to 0.03937, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0394 - 340ms/epoch - 26ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.03937 to 0.03609, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0361 - 343ms/epoch - 26ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.03609 to 0.03426, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0343 - 342ms/epoch - 26ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.03426 to 0.03414, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0341 - 356ms/epoch - 27ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.03414 to 0.03306, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0331 - 364ms/epoch - 28ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.03306 to 0.03204, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0320 - 349ms/epoch - 27ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.03204
# 13/13 - 0s - loss: 0.0324 - 304ms/epoch - 23ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.03204
# 13/13 - 0s - loss: 0.0323 - 306ms/epoch - 24ms/step
# Epoch 16/80
#
# Epoch 16: loss improved from 0.03204 to 0.03182, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0318 - 335ms/epoch - 26ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.03182
# 13/13 - 0s - loss: 0.0332 - 296ms/epoch - 23ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.03182
# 13/13 - 0s - loss: 0.0319 - 322ms/epoch - 25ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.03182 to 0.03002, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0300 - 341ms/epoch - 26ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.03002
# 13/13 - 0s - loss: 0.0301 - 301ms/epoch - 23ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.03002
# 13/13 - 0s - loss: 0.0337 - 293ms/epoch - 23ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.03002
# 13/13 - 0s - loss: 0.0326 - 185ms/epoch - 14ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.03002
# 13/13 - 0s - loss: 0.0323 - 193ms/epoch - 15ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.03002
# 13/13 - 0s - loss: 0.0327 - 188ms/epoch - 14ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.03002 to 0.02995, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0300 - 215ms/epoch - 17ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.02995 to 0.02949, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0295 - 250ms/epoch - 19ms/step
# Epoch 27/80
#
# Epoch 27: loss improved from 0.02949 to 0.02894, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0289 - 225ms/epoch - 17ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.02894
# 13/13 - 0s - loss: 0.0291 - 201ms/epoch - 15ms/step
# Epoch 29/80
#
# Epoch 29: loss improved from 0.02894 to 0.02802, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0280 - 227ms/epoch - 17ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.02802
# 13/13 - 0s - loss: 0.0281 - 207ms/epoch - 16ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.02802
# 13/13 - 0s - loss: 0.0284 - 211ms/epoch - 16ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.02802 to 0.02781, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0278 - 236ms/epoch - 18ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.02781
# 13/13 - 0s - loss: 0.0292 - 191ms/epoch - 15ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.02781
# 13/13 - 0s - loss: 0.0290 - 194ms/epoch - 15ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.02781
# 13/13 - 0s - loss: 0.0278 - 215ms/epoch - 17ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.02781
# 13/13 - 0s - loss: 0.0289 - 205ms/epoch - 16ms/step
# Epoch 37/80
#
# Epoch 37: loss improved from 0.02781 to 0.02750, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0275 - 220ms/epoch - 17ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.02750
# 13/13 - 0s - loss: 0.0290 - 205ms/epoch - 16ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.02750 to 0.02737, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0274 - 228ms/epoch - 18ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.02737
# 13/13 - 0s - loss: 0.0285 - 209ms/epoch - 16ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.02737
# 13/13 - 0s - loss: 0.0287 - 193ms/epoch - 15ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.02737
# 13/13 - 0s - loss: 0.0286 - 201ms/epoch - 15ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.02737
# 13/13 - 0s - loss: 0.0285 - 192ms/epoch - 15ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.02737
# 13/13 - 0s - loss: 0.0283 - 194ms/epoch - 15ms/step
# Epoch 45/80
#
# Epoch 45: loss improved from 0.02737 to 0.02684, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0268 - 241ms/epoch - 19ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.02684
# 13/13 - 0s - loss: 0.0272 - 192ms/epoch - 15ms/step
# Epoch 47/80
#
# Epoch 47: loss improved from 0.02684 to 0.02681, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0268 - 214ms/epoch - 16ms/step
# Epoch 48/80
#
# Epoch 48: loss improved from 0.02681 to 0.02646, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0265 - 229ms/epoch - 18ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.02646
# 13/13 - 0s - loss: 0.0268 - 208ms/epoch - 16ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.02646
# 13/13 - 0s - loss: 0.0299 - 204ms/epoch - 16ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.02646
# 13/13 - 0s - loss: 0.0270 - 197ms/epoch - 15ms/step
# Epoch 52/80
#
# Epoch 52: loss improved from 0.02646 to 0.02633, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0263 - 226ms/epoch - 17ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0268 - 190ms/epoch - 15ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0281 - 209ms/epoch - 16ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0293 - 201ms/epoch - 15ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0278 - 188ms/epoch - 14ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0282 - 212ms/epoch - 16ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0265 - 211ms/epoch - 16ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0271 - 193ms/epoch - 15ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0274 - 197ms/epoch - 15ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02633
# 13/13 - 0s - loss: 0.0270 - 187ms/epoch - 14ms/step
# Epoch 62/80
#
# Epoch 62: loss improved from 0.02633 to 0.02625, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0262 - 232ms/epoch - 18ms/step
# Epoch 63/80
#
# Epoch 63: loss improved from 0.02625 to 0.02605, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0261 - 235ms/epoch - 18ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0270 - 201ms/epoch - 15ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0274 - 184ms/epoch - 14ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0265 - 182ms/epoch - 14ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0267 - 196ms/epoch - 15ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0265 - 193ms/epoch - 15ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0265 - 287ms/epoch - 22ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0262 - 301ms/epoch - 23ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0267 - 295ms/epoch - 23ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02605
# 13/13 - 0s - loss: 0.0275 - 315ms/epoch - 24ms/step
# Epoch 73/80
#
# Epoch 73: loss improved from 0.02605 to 0.02551, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0255 - 342ms/epoch - 26ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02551
# 13/13 - 0s - loss: 0.0269 - 298ms/epoch - 23ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02551
# 13/13 - 0s - loss: 0.0263 - 305ms/epoch - 23ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02551
# 13/13 - 0s - loss: 0.0290 - 297ms/epoch - 23ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02551
# 13/13 - 0s - loss: 0.0273 - 300ms/epoch - 23ms/step
# Epoch 78/80
#
# Epoch 78: loss improved from 0.02551 to 0.02538, saving model to save_model_5_3_2.hdf5
# 13/13 - 0s - loss: 0.0254 - 354ms/epoch - 27ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02538
# 13/13 - 0s - loss: 0.0266 - 298ms/epoch - 23ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02538
# 13/13 - 0s - loss: 0.0291 - 297ms/epoch - 23ms/step

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_5_3_2.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 20/20 [==============================] - 1s 5ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 12/12 [==============================] - 0s 5ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 8/8 [==============================] - 0s 6ms/step

# %%
# Predict the next 30 days
x_input=sc_train[sc_train.shape[0]-5:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

lst_output=[]
n_steps=5
i=0
while(i<30):
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1

# Print the final list of predictions
print(lst_output)
# Out:
# [0.6961895]
# 6
# [0.6961895]
# 7
# [0.6961895]
# 8
# [0.6961895]
# 9
# [0.6961895]
# 10
# [0.6961895]
# 11
# [0.6961895]
# 12
# [0.6961895]
# 13
# [0.6961895]
# 14
# [0.6961895]
# 15
# [0.6961895]
# 16
# [0.6961895]
# 17
# [0.6961895]
# 18
# [0.6961895]
# 19
# [0.6961895]
# 20
# [0.6961895]
# 21
# [0.6961895]
# 22
# [0.6961895]
# 23
# [0.6961895]
# 24
# [0.6961895]
# 25
# [0.6961895]
# 26
# [0.6961895]
# 27
# [0.6961895]
# 28
# [0.6961895]
# 29
# [0.6961895]
# 30
# [0.6961895]
# 31
# [0.6961895]
# 32
# [0.6961895]
# 33
# [0.6961895]
# 34
# [0.6961895]
# 35
# [[0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251], [0.6961895227432251]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Silver Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  0.5278299255768458
# MAPE:  2.138090390412557
# RMSE:  0.6870788434647659
#
# ** Validate **
# MAE:  0.5209283801317215
# MAPE:  2.451469657685949
# RMSE:  0.6752492818726531

# %% [markdown]
# # Evaluate Model
#
# ---
# ![image.png](data:image/png;base64,...)
