# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow --quiet

# %%
# !pip install keras-self-attention --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for keras-self-attention (setup.py) ... done

# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import libraries for working with dates and times
import datetime as dt

# Import TensorFlow and Keras libraries for building and training neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, Reshape, Flatten
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

# Import scikit-learn library for various metrics and preprocessing tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Import matplotlib library for creating plots and charts
import matplotlib.pyplot as plt

# Magic command to display plots inline in the Jupyter Notebook
# %matplotlib inline

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# Read in the Silver dataset from a CSV file
df=pd.read_csv("/content/drive/MyDrive/PTDLKD/Data/Silver_Data.csv")
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %% [markdown]
# # Preprocessing Data
#
# ---

# %%
# Format column Date
df.index = pd.to_datetime(df.index,format='%m/%d/%Y')

# Flip the column
df = df.iloc[::-1]

# Create new Dataframe
df1 = pd.DataFrame(df, columns=['Date', 'Price'])
df1.drop('Date', axis = 1, inplace = True)

# Plot the 'price' column of the 'df' DataFrame
plt.figure(figsize=(16,5))
plt.plot(df1['Price'])
plt.title('Prices of Silver')
plt.show()

# %% [markdown]
# # Split dataset (7-2-1)
#
# ---

# %%
# Convert the 'df1' DataFrame to a NumPy array
data = df1.values

# Split the data (7-2-1)
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create a MinMaxScaler object with a specified range
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
from keras.models import Model
from keras.layers import Dense, Input, SimpleRNN, Attention

input_seq = Input(shape=(5, 1))
rnn_output = SimpleRNN(50, return_sequences=True)(input_seq)
attention_output = Attention()([rnn_output, rnn_output])
reshaped_output = Reshape((-1,))(attention_output)
output = Dense(1)(reshaped_output)

model = Model(inputs=input_seq, outputs=output)
model.compile(loss='mean_squared_error', optimizer='adam')

save_model = 'save_model(7-2-1).hdf5'
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.03397, saving model to save_model(7-2-1).hdf5
# 20/20 - 1s - loss: 0.0340 - 1s/epoch - 53ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.03397 to 0.00368, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0037 - 53ms/epoch - 3ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.00368 to 0.00145, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0014 - 52ms/epoch - 3ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.00145 to 0.00127, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0013 - 53ms/epoch - 3ms/step
# Epoch 5/80
#
# Epoch 5: loss did not improve from 0.00127
# 20/20 - 0s - loss: 0.0013 - 48ms/epoch - 2ms/step
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.00127
# 20/20 - 0s - loss: 0.0013 - 41ms/epoch - 2ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.00127 to 0.00126, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0013 - 53ms/epoch - 3ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.00126
# 20/20 - 0s - loss: 0.0013 - 40ms/epoch - 2ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.00126 to 0.00123, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0012 - 56ms/epoch - 3ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.00123 to 0.00122, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0012 - 60ms/epoch - 3ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.00122 to 0.00120, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0012 - 57ms/epoch - 3ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.00120
# 20/20 - 0s - loss: 0.0012 - 39ms/epoch - 2ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.00120 to 0.00117, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0012 - 53ms/epoch - 3ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.00117
# 20/20 - 0s - loss: 0.0012 - 38ms/epoch - 2ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.00117
# 20/20 - 0s - loss: 0.0012 - 43ms/epoch - 2ms/step
# Epoch 16/80
#
# Epoch 16: loss improved from 0.00117 to 0.00114, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0011 - 56ms/epoch - 3ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.00114
# 20/20 - 0s - loss: 0.0012 - 80ms/epoch - 4ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.00114 to 0.00112, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0011 - 79ms/epoch - 4ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.00112 to 0.00112, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0011 - 83ms/epoch - 4ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.00112
# 20/20 - 0s - loss: 0.0011 - 65ms/epoch - 3ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.00112 to 0.00112, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0011 - 54ms/epoch - 3ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.00112 to 0.00111, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0011 - 55ms/epoch - 3ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.00111
# 20/20 - 0s - loss: 0.0011 - 60ms/epoch - 3ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.00111
# 20/20 - 0s - loss: 0.0012 - 45ms/epoch - 2ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.00111
# 20/20 - 0s - loss: 0.0011 - 40ms/epoch - 2ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.00111 to 0.00106, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0011 - 60ms/epoch - 3ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.00106
# 20/20 - 0s - loss: 0.0011 - 42ms/epoch - 2ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.00106
# 20/20 - 0s - loss: 0.0011 - 42ms/epoch - 2ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.00106
# 20/20 - 0s - loss: 0.0011 - 39ms/epoch - 2ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.00106 to 0.00105, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0010 - 59ms/epoch - 3ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.00105 to 0.00102, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0010 - 53ms/epoch - 3ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.00102 to 0.00101, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 0.0010 - 54ms/epoch - 3ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.00101
# 20/20 - 0s - loss: 0.0010 - 41ms/epoch - 2ms/step
# Epoch 34/80
#
# Epoch 34: loss improved from 0.00101 to 0.00096, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 9.6284e-04 - 67ms/epoch - 3ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.00096
# 20/20 - 0s - loss: 0.0010 - 41ms/epoch - 2ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.00096
# 20/20 - 0s - loss: 9.7941e-04 - 42ms/epoch - 2ms/step
# Epoch 37/80
#
# Epoch 37: loss improved from 0.00096 to 0.00095, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 9.5284e-04 - 65ms/epoch - 3ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.00095
# 20/20 - 0s - loss: 9.6036e-04 - 41ms/epoch - 2ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.00095 to 0.00092, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 9.2447e-04 - 56ms/epoch - 3ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.00092
# 20/20 - 0s - loss: 9.3817e-04 - 41ms/epoch - 2ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.00092
# 20/20 - 0s - loss: 9.3418e-04 - 42ms/epoch - 2ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.00092
# 20/20 - 0s - loss: 9.8491e-04 - 43ms/epoch - 2ms/step
# Epoch 43/80
#
# Epoch 43: loss improved from 0.00092 to 0.00090, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 9.0235e-04 - 61ms/epoch - 3ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.00090
# 20/20 - 0s - loss: 9.7668e-04 - 43ms/epoch - 2ms/step
# Epoch 45/80
#
# Epoch 45: loss improved from 0.00090 to 0.00089, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 8.8695e-04 - 60ms/epoch - 3ms/step
# Epoch 46/80
#
# Epoch 46: loss improved from 0.00089 to 0.00087, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 8.6637e-04 - 56ms/epoch - 3ms/step
# Epoch 47/80
#
# Epoch 47: loss improved from 0.00087 to 0.00086, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 8.6052e-04 - 55ms/epoch - 3ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.00086
# 20/20 - 0s - loss: 9.8244e-04 - 39ms/epoch - 2ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.00086
# 20/20 - 0s - loss: 9.0727e-04 - 47ms/epoch - 2ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.00086
# 20/20 - 0s - loss: 9.1805e-04 - 42ms/epoch - 2ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.00086
# 20/20 - 0s - loss: 8.7369e-04 - 38ms/epoch - 2ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.00086
# 20/20 - 0s - loss: 8.8652e-04 - 38ms/epoch - 2ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.00086
# 20/20 - 0s - loss: 0.0010 - 44ms/epoch - 2ms/step
# Epoch 54/80
#
# Epoch 54: loss improved from 0.00086 to 0.00083, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 8.2826e-04 - 62ms/epoch - 3ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.00083
# 20/20 - 0s - loss: 8.6027e-04 - 42ms/epoch - 2ms/step
# Epoch 56/80
#
# Epoch 56: loss improved from 0.00083 to 0.00082, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 8.2308e-04 - 52ms/epoch - 3ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.00082
# 20/20 - 0s - loss: 8.6401e-04 - 40ms/epoch - 2ms/step
# Epoch 58/80
#
# Epoch 58: loss improved from 0.00082 to 0.00080, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 8.0400e-04 - 51ms/epoch - 3ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.00080
# 20/20 - 0s - loss: 8.1420e-04 - 48ms/epoch - 2ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.00080
# 20/20 - 0s - loss: 8.4600e-04 - 42ms/epoch - 2ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.00080
# 20/20 - 0s - loss: 8.7750e-04 - 41ms/epoch - 2ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.00080
# 20/20 - 0s - loss: 8.3913e-04 - 38ms/epoch - 2ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.00080
# 20/20 - 0s - loss: 8.3695e-04 - 39ms/epoch - 2ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.00080
# 20/20 - 0s - loss: 9.3001e-04 - 77ms/epoch - 4ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.00080
# 20/20 - 0s - loss: 8.1589e-04 - 61ms/epoch - 3ms/step
# Epoch 66/80
#
# Epoch 66: loss improved from 0.00080 to 0.00077, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 7.7131e-04 - 100ms/epoch - 5ms/step
# Epoch 67/80
#
# Epoch 67: loss improved from 0.00077 to 0.00074, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 7.4415e-04 - 90ms/epoch - 4ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.00074
# 20/20 - 0s - loss: 7.5365e-04 - 69ms/epoch - 3ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.00074
# 20/20 - 0s - loss: 8.2034e-04 - 59ms/epoch - 3ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.00074
# 20/20 - 0s - loss: 7.7527e-04 - 60ms/epoch - 3ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.00074
# 20/20 - 0s - loss: 7.5905e-04 - 112ms/epoch - 6ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.00074
# 20/20 - 0s - loss: 8.4681e-04 - 82ms/epoch - 4ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.00074
# 20/20 - 0s - loss: 7.5848e-04 - 62ms/epoch - 3ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.00074
# 20/20 - 0s - loss: 7.6750e-04 - 54ms/epoch - 3ms/step
# Epoch 75/80
#
# Epoch 75: loss improved from 0.00074 to 0.00073, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 7.2750e-04 - 92ms/epoch - 5ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.00073
# 20/20 - 0s - loss: 8.2728e-04 - 70ms/epoch - 3ms/step
# Epoch 77/80
#
# Epoch 77: loss improved from 0.00073 to 0.00069, saving model to save_model(7-2-1).hdf5
# 20/20 - 0s - loss: 6.9400e-04 - 121ms/epoch - 6ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.00069
# 20/20 - 0s - loss: 7.8721e-04 - 70ms/epoch - 3ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.00069
# 20/20 - 0s - loss: 0.0011 - 69ms/epoch - 3ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.00069
# 20/20 - 0s - loss: 0.0013 - 70ms/epoch - 4ms/step

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model(7-2-1).hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 31/31 [==============================] - 0s 3ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[sc_train.shape[0]-5:].reshape(1, -1)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Initialize variables
lst_output = []
n_steps = 5
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 5):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps,1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.6711223125457764], [0.6501696109771729], [0.610351026058197], [0.5860269665718079], [0.5646159052848816], [0.5397155284881592], [0.521450400352478], [0.49969491362571716], [0.48059770464897156], [0.4625949561595917], [0.4444325566291809], [0.4283604323863983], [0.4122568964958191], [0.397239625453949], [0.3829929232597351], [0.36918380856513977], [0.35627880692481995], [0.3438148498535156], [0.33199506998062134], [0.3207383155822754], [0.30994534492492676], [0.2996956706047058], [0.2898717224597931], [0.28049665689468384], [0.27153709530830383], [0.2629544734954834], [0.2547506093978882], [0.24688588082790375], [0.23935171961784363], [0.23212848603725433]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['Date'].astype(str).tolist()

# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%m/%d/%Y').date() for date in datelist_train]

# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Silver Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  0.4041476920378124
# MAPE:  1.8284930320904298
# RMSE:  0.531895984166395
#
# ** Validate **
# MAE:  0.45360785061496106
# MAPE:  1.927080633204241
# RMSE:  0.5688340476510796

# %% [markdown]
# # Split dataset (6-3-1)
#
# ---

# %%
# 4. Split data (6-3-1)
train_size = int(0.6 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 64 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(units=64, input_shape=(x_train.shape[1], 1), return_sequences=True,kernel_regularizer=l2(0.01)))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=True))

# Add a dropout layer with a rate of 0.5
model.add(Dropout(0.5))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=False))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_6_3_1.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.23214, saving model to save_model_6_3_1.hdf5
# 17/17 - 10s - loss: 0.2321 - 10s/epoch - 583ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.23214 to 0.10549, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.1055 - 396ms/epoch - 23ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.10549 to 0.05652, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0565 - 300ms/epoch - 18ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.05652 to 0.05008, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0501 - 333ms/epoch - 20ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.05008 to 0.04593, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0459 - 279ms/epoch - 16ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.04593 to 0.04108, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0411 - 300ms/epoch - 18ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.04108 to 0.03715, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0371 - 234ms/epoch - 14ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.03715 to 0.03641, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0364 - 178ms/epoch - 10ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.03641 to 0.03470, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0347 - 175ms/epoch - 10ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.03470 to 0.03419, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0342 - 177ms/epoch - 10ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.03419
# 17/17 - 0s - loss: 0.0342 - 163ms/epoch - 10ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.03419 to 0.03193, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0319 - 176ms/epoch - 10ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.03193
# 17/17 - 0s - loss: 0.0334 - 136ms/epoch - 8ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.03193
# 17/17 - 0s - loss: 0.0323 - 142ms/epoch - 8ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.03193 to 0.03036, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0304 - 166ms/epoch - 10ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.03036
# 17/17 - 0s - loss: 0.0314 - 158ms/epoch - 9ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.03036
# 17/17 - 0s - loss: 0.0315 - 147ms/epoch - 9ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.03036
# 17/17 - 0s - loss: 0.0331 - 158ms/epoch - 9ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.03036
# 17/17 - 0s - loss: 0.0324 - 142ms/epoch - 8ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.03036
# 17/17 - 0s - loss: 0.0308 - 147ms/epoch - 9ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.03036
# 17/17 - 0s - loss: 0.0343 - 146ms/epoch - 9ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.03036 to 0.03006, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0301 - 166ms/epoch - 10ms/step
# Epoch 23/80
#
# Epoch 23: loss improved from 0.03006 to 0.02956, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0296 - 172ms/epoch - 10ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.02956
# 17/17 - 0s - loss: 0.0296 - 161ms/epoch - 9ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.02956
# 17/17 - 0s - loss: 0.0304 - 145ms/epoch - 9ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02956
# 17/17 - 0s - loss: 0.0319 - 142ms/epoch - 8ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02956
# 17/17 - 0s - loss: 0.0315 - 157ms/epoch - 9ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.02956
# 17/17 - 0s - loss: 0.0318 - 152ms/epoch - 9ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.02956
# 17/17 - 0s - loss: 0.0299 - 148ms/epoch - 9ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.02956 to 0.02897, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0290 - 197ms/epoch - 12ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.02897
# 17/17 - 0s - loss: 0.0295 - 145ms/epoch - 9ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.02897 to 0.02878, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0288 - 163ms/epoch - 10ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.02878
# 17/17 - 0s - loss: 0.0293 - 145ms/epoch - 9ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.02878
# 17/17 - 0s - loss: 0.0313 - 142ms/epoch - 8ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.02878 to 0.02843, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0284 - 166ms/epoch - 10ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.02843
# 17/17 - 0s - loss: 0.0285 - 160ms/epoch - 9ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.02843
# 17/17 - 0s - loss: 0.0289 - 163ms/epoch - 10ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.02843
# 17/17 - 0s - loss: 0.0289 - 152ms/epoch - 9ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.02843
# 17/17 - 0s - loss: 0.0289 - 159ms/epoch - 9ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.02843
# 17/17 - 0s - loss: 0.0303 - 145ms/epoch - 9ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.02843
# 17/17 - 0s - loss: 0.0294 - 150ms/epoch - 9ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.02843
# 17/17 - 0s - loss: 0.0285 - 150ms/epoch - 9ms/step
# Epoch 43/80
#
# Epoch 43: loss improved from 0.02843 to 0.02813, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0281 - 177ms/epoch - 10ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.02813 to 0.02794, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0279 - 168ms/epoch - 10ms/step
# Epoch 45/80
#
# Epoch 45: loss improved from 0.02794 to 0.02778, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0278 - 165ms/epoch - 10ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.02778
# 17/17 - 0s - loss: 0.0285 - 148ms/epoch - 9ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.02778
# 17/17 - 0s - loss: 0.0285 - 155ms/epoch - 9ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.02778
# 17/17 - 0s - loss: 0.0297 - 146ms/epoch - 9ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.02778
# 17/17 - 0s - loss: 0.0296 - 170ms/epoch - 10ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.02778
# 17/17 - 0s - loss: 0.0316 - 227ms/epoch - 13ms/step
# Epoch 51/80
#
# Epoch 51: loss improved from 0.02778 to 0.02737, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0274 - 245ms/epoch - 14ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.02737
# 17/17 - 0s - loss: 0.0280 - 204ms/epoch - 12ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.02737
# 17/17 - 0s - loss: 0.0283 - 209ms/epoch - 12ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02737
# 17/17 - 0s - loss: 0.0282 - 222ms/epoch - 13ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02737
# 17/17 - 0s - loss: 0.0274 - 215ms/epoch - 13ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.02737
# 17/17 - 0s - loss: 0.0283 - 220ms/epoch - 13ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02737
# 17/17 - 0s - loss: 0.0276 - 212ms/epoch - 12ms/step
# Epoch 58/80
#
# Epoch 58: loss improved from 0.02737 to 0.02630, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0263 - 240ms/epoch - 14ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02630
# 17/17 - 0s - loss: 0.0283 - 219ms/epoch - 13ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02630
# 17/17 - 0s - loss: 0.0302 - 212ms/epoch - 12ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02630
# 17/17 - 0s - loss: 0.0290 - 210ms/epoch - 12ms/step
# Epoch 62/80
#
# Epoch 62: loss improved from 0.02630 to 0.02628, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0263 - 229ms/epoch - 13ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0265 - 149ms/epoch - 9ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0269 - 160ms/epoch - 9ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0269 - 160ms/epoch - 9ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0272 - 154ms/epoch - 9ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0289 - 151ms/epoch - 9ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0279 - 155ms/epoch - 9ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0288 - 165ms/epoch - 10ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02628
# 17/17 - 0s - loss: 0.0283 - 157ms/epoch - 9ms/step
# Epoch 71/80
#
# Epoch 71: loss improved from 0.02628 to 0.02606, saving model to save_model_6_3_1.hdf5
# 17/17 - 0s - loss: 0.0261 - 164ms/epoch - 10ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0285 - 155ms/epoch - 9ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0276 - 144ms/epoch - 8ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0267 - 137ms/epoch - 8ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0298 - 145ms/epoch - 9ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0268 - 146ms/epoch - 9ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0268 - 149ms/epoch - 9ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0272 - 145ms/epoch - 9ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0287 - 151ms/epoch - 9ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02606
# 17/17 - 0s - loss: 0.0273 - 153ms/epoch - 9ms/step

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_6_3_1.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 27/27 [==============================] - 1s 3ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 14/14 [==============================] - 0s 3ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
# Predict the next 30 days
x_input=sc_train[sc_train.shape[0]-5:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

lst_output=[]
n_steps=5
i=0
while(i<30):
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1

# Print the final list of predictions
print(lst_output)
# Out:
# [0.6834358]
# 6
# [0.6834358]
# 7
# [0.6834358]
# 8
# [0.6834358]
# 9
# [0.6834358]
# 10
# [0.6834358]
# 11
# [0.6834358]
# 12
# [0.6834358]
# 13
# [0.6834358]
# 14
# [0.6834358]
# 15
# [0.6834358]
# 16
# [0.6834358]
# 17
# [0.6834358]
# 18
# [0.6834358]
# 19
# [0.6834358]
# 20
# [0.6834358]
# 21
# [0.6834358]
# 22
# [0.6834358]
# 23
# [0.6834358]
# 24
# [0.6834358]
# 25
# [0.6834358]
# 26
# [0.6834358]
# 27
# [0.6834358]
# 28
# [0.6834358]
# 29
# [0.6834358]
# 30
# [0.6834358]
# 31
# [0.6834358]
# 32
# [0.6834358]
# 33
# [0.6834358]
# 34
# [0.6834358]
# 35
# [[0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452], [0.6834357976913452]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Silver Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  0.5478578096425758
# MAPE:  2.3960178036502566
# RMSE:  0.6850381602621307
#
# ** Validate **
# MAE:  0.5155822081230055
# MAPE:  2.2046180601039738
# RMSE:  0.6577574419971427

# %% [markdown]
# # Split dataset (5-3-2)
#
# ---

# %%
# 4. Split data
train_size = int(0.5 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 64 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(units=64, input_shape=(x_train.shape[1], 1), return_sequences=True,kernel_regularizer=l2(0.01)))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=True))

# Add a dropout layer with a rate of 0.5
model.add(Dropout(0.5))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=False))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_5_3_2.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.17542, saving model to save_model_5_3_2.hdf5
# 15/15 - 5s - loss: 0.1754 - 5s/epoch - 341ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.17542 to 0.08518, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0852 - 146ms/epoch - 10ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.08518 to 0.06969, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0697 - 150ms/epoch - 10ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.06969 to 0.04692, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0469 - 148ms/epoch - 10ms/step
# Epoch 5/80
#
# Epoch 5: loss did not improve from 0.04692
# 15/15 - 0s - loss: 0.0518 - 125ms/epoch - 8ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.04692 to 0.04293, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0429 - 161ms/epoch - 11ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.04293 to 0.03497, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0350 - 156ms/epoch - 10ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.03497 to 0.03273, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0327 - 152ms/epoch - 10ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.03273
# 15/15 - 0s - loss: 0.0328 - 146ms/epoch - 10ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.03273 to 0.02990, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0299 - 147ms/epoch - 10ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.02990
# 15/15 - 0s - loss: 0.0349 - 133ms/epoch - 9ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.02990
# 15/15 - 0s - loss: 0.0304 - 140ms/epoch - 9ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.02990
# 15/15 - 0s - loss: 0.0299 - 121ms/epoch - 8ms/step
# Epoch 14/80
#
# Epoch 14: loss improved from 0.02990 to 0.02852, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0285 - 144ms/epoch - 10ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.02852 to 0.02624, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0262 - 145ms/epoch - 10ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.02624
# 15/15 - 0s - loss: 0.0286 - 128ms/epoch - 9ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.02624
# 15/15 - 0s - loss: 0.0272 - 128ms/epoch - 9ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.02624
# 15/15 - 0s - loss: 0.0265 - 130ms/epoch - 9ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.02624
# 15/15 - 0s - loss: 0.0268 - 130ms/epoch - 9ms/step
# Epoch 20/80
#
# Epoch 20: loss improved from 0.02624 to 0.02619, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0262 - 156ms/epoch - 10ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.02619
# 15/15 - 0s - loss: 0.0266 - 136ms/epoch - 9ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.02619 to 0.02568, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0257 - 154ms/epoch - 10ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.02568
# 15/15 - 0s - loss: 0.0260 - 129ms/epoch - 9ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.02568 to 0.02565, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0257 - 155ms/epoch - 10ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.02565
# 15/15 - 0s - loss: 0.0263 - 127ms/epoch - 8ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02565
# 15/15 - 0s - loss: 0.0273 - 135ms/epoch - 9ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02565
# 15/15 - 0s - loss: 0.0274 - 135ms/epoch - 9ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.02565
# 15/15 - 0s - loss: 0.0266 - 144ms/epoch - 10ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.02565
# 15/15 - 0s - loss: 0.0285 - 123ms/epoch - 8ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.02565 to 0.02529, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0253 - 149ms/epoch - 10ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.02529
# 15/15 - 0s - loss: 0.0265 - 135ms/epoch - 9ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.02529 to 0.02479, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0248 - 147ms/epoch - 10ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0268 - 122ms/epoch - 8ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0260 - 150ms/epoch - 10ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0291 - 127ms/epoch - 8ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0254 - 125ms/epoch - 8ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0329 - 123ms/epoch - 8ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0261 - 135ms/epoch - 9ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0268 - 129ms/epoch - 9ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0308 - 129ms/epoch - 9ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0285 - 132ms/epoch - 9ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0255 - 128ms/epoch - 9ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.02479
# 15/15 - 0s - loss: 0.0260 - 125ms/epoch - 8ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.02479 to 0.02463, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0246 - 147ms/epoch - 10ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.02463
# 15/15 - 0s - loss: 0.0301 - 124ms/epoch - 8ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.02463
# 15/15 - 0s - loss: 0.0289 - 117ms/epoch - 8ms/step
# Epoch 47/80
#
# Epoch 47: loss improved from 0.02463 to 0.02443, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0244 - 135ms/epoch - 9ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.02443
# 15/15 - 0s - loss: 0.0248 - 124ms/epoch - 8ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.02443
# 15/15 - 0s - loss: 0.0252 - 133ms/epoch - 9ms/step
# Epoch 50/80
#
# Epoch 50: loss improved from 0.02443 to 0.02407, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0241 - 146ms/epoch - 10ms/step
# Epoch 51/80
#
# Epoch 51: loss improved from 0.02407 to 0.02308, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0231 - 155ms/epoch - 10ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.02308
# 15/15 - 0s - loss: 0.0236 - 135ms/epoch - 9ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.02308
# 15/15 - 0s - loss: 0.0281 - 132ms/epoch - 9ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02308
# 15/15 - 0s - loss: 0.0270 - 129ms/epoch - 9ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02308
# 15/15 - 0s - loss: 0.0243 - 128ms/epoch - 9ms/step
# Epoch 56/80
#
# Epoch 56: loss improved from 0.02308 to 0.02304, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0230 - 165ms/epoch - 11ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02304
# 15/15 - 0s - loss: 0.0231 - 130ms/epoch - 9ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02304
# 15/15 - 0s - loss: 0.0235 - 126ms/epoch - 8ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02304
# 15/15 - 0s - loss: 0.0255 - 119ms/epoch - 8ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02304
# 15/15 - 0s - loss: 0.0239 - 131ms/epoch - 9ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02304
# 15/15 - 0s - loss: 0.0242 - 125ms/epoch - 8ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.02304
# 15/15 - 0s - loss: 0.0257 - 117ms/epoch - 8ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.02304
# 15/15 - 0s - loss: 0.0244 - 126ms/epoch - 8ms/step
# Epoch 64/80
#
# Epoch 64: loss improved from 0.02304 to 0.02267, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0227 - 168ms/epoch - 11ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02267
# 15/15 - 0s - loss: 0.0233 - 132ms/epoch - 9ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02267
# 15/15 - 0s - loss: 0.0240 - 131ms/epoch - 9ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02267
# 15/15 - 0s - loss: 0.0231 - 131ms/epoch - 9ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.02267
# 15/15 - 0s - loss: 0.0257 - 129ms/epoch - 9ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02267
# 15/15 - 0s - loss: 0.0238 - 124ms/epoch - 8ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02267
# 15/15 - 0s - loss: 0.0228 - 127ms/epoch - 8ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02267
# 15/15 - 0s - loss: 0.0234 - 127ms/epoch - 8ms/step
# Epoch 72/80
#
# Epoch 72: loss improved from 0.02267 to 0.02256, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0226 - 229ms/epoch - 15ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.02256
# 15/15 - 0s - loss: 0.0226 - 192ms/epoch - 13ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02256
# 15/15 - 0s - loss: 0.0241 - 190ms/epoch - 13ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02256
# 15/15 - 0s - loss: 0.0233 - 194ms/epoch - 13ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02256
# 15/15 - 0s - loss: 0.0229 - 186ms/epoch - 12ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02256
# 15/15 - 0s - loss: 0.0261 - 194ms/epoch - 13ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02256
# 15/15 - 0s - loss: 0.0247 - 189ms/epoch - 13ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02256
# 15/15 - 0s - loss: 0.0226 - 183ms/epoch - 12ms/step
# Epoch 80/80
#
# Epoch 80: loss improved from 0.02256 to 0.02211, saving model to save_model_5_3_2.hdf5
# 15/15 - 0s - loss: 0.0221 - 217ms/epoch - 14ms/step

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.hdf5 file
final_model = load_model('save_model_5_3_2.hdf5')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 22/22 [==============================] - 1s 3ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 14/14 [==============================] - 0s 3ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-5:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(5, val.shape[0]):
    x_val.append(sc_val[i-5:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 3ms/step

# %%
# Predict the next 30 days
x_input=sc_train[sc_train.shape[0]-5:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

lst_output=[]
n_steps=5
i=0
while(i<30):
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1

# Print the final list of predictions
print(lst_output)
# Out:
# [0.7023941]
# 6
# [0.7023941]
# 7
# [0.7023941]
# 8
# [0.7023941]
# 9
# [0.7023941]
# 10
# [0.7023941]
# 11
# [0.7023941]
# 12
# [0.7023941]
# 13
# [0.7023941]
# 14
# [0.7023941]
# 15
# [0.7023941]
# 16
# [0.7023941]
# 17
# [0.7023941]
# 18
# [0.7023941]
# 19
# [0.7023941]
# 20
# [0.7023941]
# 21
# [0.7023941]
# 22
# [0.7023941]
# 23
# [0.7023941]
# 24
# [0.7023941]
# 25
# [0.7023941]
# 26
# [0.7023941]
# 27
# [0.7023941]
# 28
# [0.7023941]
# 29
# [0.7023941]
# 30
# [0.7023941]
# 31
# [0.7023941]
# 32
# [0.7023941]
# 33
# [0.7023941]
# 34
# [0.7023941]
# 35
# [[0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642], [0.7023941278457642]]

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['price']).set_index(pd.Series(datelist_future))

# Set the figure size and create a subplot
plt.figure(figsize=(16,5))

# Create a plot to compare the predicted and true values for the training and test data
plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Price[train_size-100:])
plt.plot(test_data)

# Plot the actual and predicted prices in the test set, and the predicted future prices
plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Silver Prices Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction'])
plt.show()

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  0.680586667942551
# MAPE:  2.7623226094702495
# RMSE:  0.9078927845087416
#
# ** Validate **
# MAE:  0.5762662334644331
# MAPE:  2.704888017860345
# RMSE:  0.7325915515222176

# %% [markdown]
# # Evaluate Model
#
# ---
# ![image.png](data:image/png;base64,...)
